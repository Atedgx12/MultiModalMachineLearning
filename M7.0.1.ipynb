# %%
###-----------------------------
#1. Import Libraries
#-----------------------------
#In this section, we import all the necessary libraries required for the program. 
#These include standard libraries for system operations, numerical computations, data handling, visualization, GUI development, model architectures,
#and more. These imports are essential for building and training our machine learning models, handling data, and creating a user interface.

# %%
import os
import sys
import math
import json
import queue
import logging
import random
import threading
from io import BytesIO

# Numerical & Data Handling
import numpy as np
import torch
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import autocast, GradScaler
from sklearn.model_selection import train_test_split

# Visualization & GUI
import matplotlib
matplotlib.use('TkAgg')  # Use Tkinter-compatible backend for Matplotlib
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from mpl_toolkits.mplot3d import Axes3D  # For 3D plots

import tkinter as tk
from tkinter import ttk, filedialog, messagebox
from PIL import Image, ImageTk

# Model Architectures
from torchvision.models import resnet18, ResNet18_Weights

# Tree Structure & Visualization
from anytree import NodeMixin, RenderTree
from anytree.exporter import DotExporter

# Learning Rate Schedulers
from torch.optim import lr_scheduler
from dataclasses import dataclass
from graphviz import Source
from concurrent.futures import ThreadPoolExecutor, as_completed

from tqdm import tqdm  # For progress bars
import time
from PIL import Image, ImageTk, ImageDraw

# %%
#-----------------------------
#2. Configure Logging and Seed
#-----------------------------
#In this section, we set up logging to capture information during execution and define a function to set random seeds for reproducibility.
#We also define a function to add noise and dead squares to grids, which is useful for data augmentation.

# %%
# Configure logging
logging.basicConfig(level=logging.INFO, stream=sys.stdout)
logger = logging.getLogger(__name__)

def add_noise_and_dead_squares(grid, noise_prob=0.1, dead_prob=0.05):
    noise_mask = np.random.rand(*grid.shape) < noise_prob
    dead_mask = np.random.rand(*grid.shape) < dead_prob

    noise = np.random.randint(0, NUM_CLASSES - 1, size=grid.shape)
    grid = np.where(noise_mask, noise, grid)
    grid = np.where(dead_mask, -1, grid)  # Assign dead squares

    return grid

# Set random seeds for reproducibility
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed()

# %%
#-----------------------------
#3. Define Constants
#-----------------------------
#Here, we define constants that will be used throughout the program. 
#This includes the number of classes (colors and dead squares) and fixed dimensions for the grids to ensure consistent processing.

# %%
# Define the number of classes
NUM_CLASSES = 11  # 0-10, where 10 represents dead squares

# Define fixed image dimensions
FIXED_HEIGHT = 32
FIXED_WIDTH = 32

# %%
#-----------------------------
#4. Define Data Structures and Loading Functions
#-----------------------------
#In this section, we define the data structures and functions necessary for loading and processing the ARC dataset. 
#We create a GridPair dataclass to hold input and output grids, functions to load JSON data, and utility functions to process and reshape grids.

# %%
# Data Class for Grid Pairs
@dataclass
class GridPair:
    task_id: str
    input_grid: np.ndarray
    output_grid: np.ndarray

def load_arc_data():
    file_paths = {
        "arc-agi_training-challenges": "arc-agi_training_challenges.json",
        "arc-agi_evaluation-challenges": "arc-agi_evaluation_challenges.json",
        "arc-agi_training-solutions": "arc-agi_training_solutions.json",
        "arc-agi_evaluation-solutions": "arc-agi_evaluation_solutions.json",
    }
    arc_data = {key: load_json_file(path) for key, path in file_paths.items()}
    return arc_data

def load_json_file(path):
    try:
        with open(path, 'r') as f:
            data = json.load(f)
            logger.info(f"Loaded data from {path}.")
            return data
    except (FileNotFoundError, json.JSONDecodeError) as e:
        logger.error(f"Error loading {path}: {e}")
        return {}

def get_device():
    """Detect the best available device: CUDA or CPU."""
    if torch.cuda.is_available():
        device = torch.device('cuda')  # CUDA GPU
        logger.info("Using NVIDIA GPU via CUDA.")
    else:
        device = torch.device('cpu')  # Fallback to CPU
        logger.info("Using CPU as fallback.")
    return device

def extract_and_reshape_grid(grid):
    try:
        # Convert to NumPy array if not already
        grid = np.array(grid)
        # Handle empty grids or grids with zero dimensions
        if grid.size == 0 or 0 in grid.shape:
            logger.error(f"Empty grid or grid with zero dimension encountered: {grid.shape}")
            return None
        # Ensure grid is 2D
        if grid.ndim == 1:
            # If the grid is 1D, reshape to (1, N)
            grid = grid.reshape(1, -1)
            logger.warning(f"Grid reshaped to 2D: {grid.shape}")
        elif grid.ndim > 2:
            grid = grid.squeeze()
            if grid.ndim > 2:
                logger.error(f"Grid has more than 2 dimensions after squeeze: {grid.shape}")
                return None
        return grid  # Return as is, without resizing
    except Exception as e:
        logger.error(f"Error processing grid: {e}")
        return None

# Flatten and Reshape Grid Data
def flatten_and_reshape(task_data):
    flattened_pairs = []
    for task_id, task_content in task_data.items():
        logger.info(f"Parsing task {task_id}...")
        train_pairs = task_content.get('train', [])
        for pair in train_pairs:
            input_grid = extract_and_reshape_grid(pair.get("input"))
            output_grid = extract_and_reshape_grid(pair.get("output"))
            if input_grid is not None and output_grid is not None:
                # Check for zero dimensions in input or output grid
                if 0 in input_grid.shape or 0 in output_grid.shape:
                    logger.warning(f"Task ID: {task_id} has grid with zero dimension. Skipping.")
                    continue
                # Store the grids even if shapes differ
                flattened_pairs.append(GridPair(task_id, input_grid, output_grid))
            else:
                logger.warning(f"Task ID: {task_id} has invalid input/output grids.")
    logger.info(f"Total valid grid pairs extracted: {len(flattened_pairs)}")
    return flattened_pairs

def grid_to_image(grid, color_map):
    img_array = np.zeros((grid.shape[0], grid.shape[1], 3), dtype=np.uint8)
    for i in range(grid.shape[0]):
        for j in range(grid.shape[1]):
            img_array[i, j] = color_map.get(grid[i, j], [0, 0, 0])  # Default to black
    return Image.fromarray(img_array)

color_map = {
    0: [0, 0, 0],       # Black
    1: [255, 0, 0],     # Red
    2: [0, 255, 0],     # Green
    3: [0, 0, 255],     # Blue
    # Add more colors as needed
}

class TreeNode(NodeMixin):
    def __init__(self, name, input_grid=None, parent=None, children=None):
        self.name = name
        self.input_grid = input_grid
        self.embedding = None
        self.parent = parent
        if children:
            self.children = children

        logger.info(f"Node '{self.name}' initialized.")

    def set_embedding(self, embedding):
        """
        Set the embedding for the node.
        """
        self.embedding = embedding
        logger.info(f"Embedding set for node '{self.name}'.")

    def __repr__(self):
        """String representation for easier debugging."""
        return f"TreeNode(name={self.name}, children={len(self.children) if self.children else 0})"

def build_data_tree(grid_pairs):
    """
    Build a hierarchical tree from the ARC data using the Node class,
    and create a task dictionary for quick access.

    Args:
        grid_pairs (list): List of GridPair objects.

    Returns:
        tuple: (Node, dict) - Root node and task dictionary.
    """
    # Create the root node
    root = TreeNode(name="ARC Dataset")

    # Initialize the task dictionary
    task_dict = {}

    # Loop through the grid pairs to build task nodes
    for idx, pair in enumerate(grid_pairs):
        try:
            if not isinstance(pair, GridPair):
                raise TypeError(f"Expected GridPair, got {type(pair)}: {pair}")

            # Ensure grids are NumPy arrays
            input_grid = np.array(pair.input_grid) if not isinstance(pair.input_grid, np.ndarray) else pair.input_grid
            output_grid = np.array(pair.output_grid) if not isinstance(pair.output_grid, np.ndarray) else pair.output_grid

            # Create task and output nodes
            task_node = TreeNode(name=f"Task {pair.task_id}", parent=root)
            output_node = TreeNode(name=f"Output {pair.task_id}", parent=task_node)

            # Set embeddings for the nodes
            task_node.set_embedding(input_grid)
            output_node.set_embedding(output_grid)

            # Store the nodes in the task dictionary
            task_dict[pair.task_id] = {
                'task_node': task_node,
                'output_node': output_node,
                'grids': (input_grid, output_grid)
            }

            # Log success
            logger.info(f"Created task node for {pair.task_id} with embedding shape: {task_node.embedding.shape}")

        except Exception as e:
            logger.exception(f"Failed to create nodes for grid pair {idx}: {e}")
            continue  # Skip this pair if there's an issue

    # Return the root node and the task dictionary
    return root, task_dict

# %%
#5. Data Augmentation Functions
#-----------------------------
#This section includes functions for augmenting the grid data to increase the diversity of the dataset.
#Functions include adding noise, rotating, flipping grids, and generating multiple augmented datasets.

# %%
def augment_grid(grid, noise_prob=0.2, dead_square_prob=0.1):
    augmented_grid = np.array(grid)

    # Ensure the grid is 2D
    if augmented_grid.ndim != 2:
        logger.error(f"Augmenting grid failed due to invalid shape: {augmented_grid.shape}")
        return augmented_grid  # Return the original grid without augmentation

    # Random noise and dead square masks
    noise_mask = np.random.rand(*augmented_grid.shape) < noise_prob
    dead_mask = np.random.rand(*augmented_grid.shape) < dead_square_prob

    # Apply noise
    noise_values = np.random.randint(0, NUM_CLASSES - 1, size=augmented_grid.shape)
    augmented_grid = np.where(noise_mask, noise_values, augmented_grid)
    augmented_grid = np.where(dead_mask, -1, augmented_grid)  # Mark as dead squares

    return augmented_grid

def rotate_grid(grid):
    """Randomly rotates the grid."""
    rotations = random.choice([0, 1, 2, 3])
    return np.rot90(grid, rotations)

def flip_grid(grid):
    """Randomly flips the grid."""
    flip_choice = random.choice(['none', 'vertical', 'horizontal'])
    if flip_choice == 'vertical':
        return np.flipud(grid)  # Vertical flip
    elif flip_choice == 'horizontal':
        return np.fliplr(grid)  # Horizontal flip
    else:
        return grid  # No flip

def generate_multiple_augmented_datasets(grid_pairs, num_augmented_sets=3):
    """
    Generates multiple augmented datasets from the input grid pairs.

    Args:
        grid_pairs (list): List of GridPair objects.
        num_augmented_sets (int): Number of augmented sets to generate.

    Returns:
        list: Augmented grid pairs.
    """
    augmented_pairs = []
    for _ in range(num_augmented_sets):
        for pair in grid_pairs:
            # Apply augmentations to input grid
            augmented_input = augment_grid(pair.input_grid)

            # Optionally rotate and flip
            augmented_input = rotate_grid(augmented_input)
            augmented_input = flip_grid(augmented_input)

            # Append the augmented input with the original target grid
            augmented_pairs.append(GridPair(pair.task_id, augmented_input, pair.output_grid))

    return augmented_pairs

# %%
#-----------------------------
#6. PyTorch Dataset Class
#-----------------------------
#Here, we define a custom PyTorch dataset class AugmentedARCDataset that handles the loading and preprocessing of the grid data. 
#It includes data augmentation and resizing of grids to fixed dimensions.

# %%
from torchvision.transforms import Resize
from PIL import Image

class AugmentedARCDataset(torch.utils.data.Dataset):
    def __init__(self, grid_pairs, augment=False):
        # Filter out pairs where input or output grid has zero dimensions
        self.grid_pairs = [
            pair for pair in grid_pairs
            if pair.input_grid.size != 0 and pair.output_grid.size != 0
            and 0 not in pair.input_grid.shape and 0 not in pair.output_grid.shape
        ]
        self.augment = augment
        self.resize = Resize((FIXED_HEIGHT, FIXED_WIDTH))
        logger.info(f"Dataset initialized with {len(self.grid_pairs)} valid grid pairs.")

    def __len__(self):
        return len(self.grid_pairs)

    def __getitem__(self, idx):
        # Get the GridPair object
        pair = self.grid_pairs[idx]

        # Access the input and target grids
        input_grid = pair.input_grid
        target_grid = pair.output_grid

        # Apply augmentation if enabled
        if self.augment:
            input_grid = augment_grid(input_grid)

        # Convert grids to PIL Images for resizing
        input_image = Image.fromarray(input_grid.astype(np.uint8))
        input_image = self.resize(input_image)
        input_grid_resized = np.array(input_image)

        # Convert to tensors
        input_tensor = torch.tensor(input_grid_resized, dtype=torch.float32).unsqueeze(0)  # Shape: [1, H, W]
        target_image = Image.fromarray(target_grid.astype(np.uint8))
        target_image = self.resize(target_image)
        target_grid_resized = np.array(target_image)
        target_tensor = torch.tensor(target_grid_resized, dtype=torch.long)

        # Ensure target_tensor is 2D
        if target_tensor.dim() > 2:
            target_tensor = target_tensor.squeeze()

        # Debugging statements
        logger.debug(f"Index {idx}:")
        logger.debug(f"  Input tensor shape: {input_tensor.shape}")
        logger.debug(f"  Target tensor shape: {target_tensor.shape}")

        return input_tensor, target_tensor

# %%
#-----------------------------
#7. Define the Deep Neural Network Models
#-----------------------------
#In this section, we define the neural network architectures used in our project. 
#This includes a convolutional neural network (CNNGridMapper) for mapping input grids to output grids and the generator and discriminator models 
#for the GAN.

# %%
class CNNGridMapper(nn.Module):
    def __init__(self, num_classes=NUM_CLASSES):
        super(CNNGridMapper, self).__init__()
        self.num_classes = num_classes

        # Use a CNN backbone (e.g., ResNet18)
        self.cnn = resnet18(weights=ResNet18_Weights.DEFAULT)

        # Modify the first convolutional layer for single-channel input
        self.cnn.conv1 = nn.Conv2d(1, 64, kernel_size=7, stride=2, padding=3, bias=False)
        nn.init.kaiming_normal_(self.cnn.conv1.weight, mode='fan_out', nonlinearity='relu')

        # Remove the fully connected layer
        self.cnn_layers = nn.Sequential(*list(self.cnn.children())[:-2])

        # Upsampling layers to recover spatial dimensions
        self.upsample = nn.Sequential(
            nn.ConvTranspose2d(512, 256, kernel_size=2, stride=2),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(256, 128, kernel_size=2, stride=2),
            nn.ReLU(inplace=True),
            nn.ConvTranspose2d(128, num_classes, kernel_size=2, stride=2)
        )

    def forward(self, x):
        x = self.cnn_layers(x)
        x = self.upsample(x)
        return x  # Output shape: (batch_size, num_classes, H', W')

class Generator(nn.Module):
    def __init__(self, latent_dim=100, output_channels=NUM_CLASSES, grid_size=(32, 32)):
        super(Generator, self).__init__()
        self.latent_dim = latent_dim
        self.output_channels = output_channels
        self.grid_size = grid_size
        self.main = nn.Sequential(
            # Input: latent_dim x 1 x 1
            nn.ConvTranspose2d(latent_dim, 512, 4, 1, 0, bias=False),
            nn.BatchNorm2d(512),
            nn.ReLU(True),
            
            # State size: 512 x 4 x 4
            nn.ConvTranspose2d(512, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.ReLU(True),
            
            # State size: 256 x 8 x 8
            nn.ConvTranspose2d(256, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(True),
            
            # State size: 128 x 16 x 16
            nn.ConvTranspose2d(128, output_channels, 4, 2, 1, bias=False),
            nn.Tanh()
        )

    def forward(self, z):
        z = z.view(-1, self.latent_dim, 1, 1)
        output = self.main(z)
        print(f"Generator output shape: {output.shape}")  # Debugging
        return output  # Expected Output: [batch_size, 11, 32, 32]

class Discriminator(nn.Module):
    def __init__(self, input_channels=NUM_CLASSES, grid_size=(32, 32)):
        super(Discriminator, self).__init__()
        self.input_channels = input_channels
        self.grid_size = grid_size
        self.main = nn.Sequential(
            # input is (input_channels) x 32 x 32
            nn.Conv2d(input_channels, 64, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            
            # State size: 64 x 16 x 16
            nn.Conv2d(64, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            
            # State size: 128 x 8 x 8
            nn.Conv2d(128, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            
            # State size: 256 x 4 x 4
            nn.Conv2d(256, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.main(x).view(-1, 1).squeeze(1)

# %%
#-----------------------------
#8. Custom Collate Function
#-----------------------------
#This section defines a custom collate function for the DataLoader to handle variable-sized inputs and targets, padding them appropriately 
#for batch processing.

# %%
# -----------------------------
# 8. Custom Collate Function
# -----------------------------

def collate_fn(batch):
    inputs = [item[0] for item in batch]  # Shape: [C, H, W]
    targets = [item[1] for item in batch]  # Shape: [H, W]

    # Find max dimensions in the batch for inputs and targets separately
    max_input_height = max(t.size(-2) for t in inputs)
    max_input_width = max(t.size(-1) for t in inputs)
    max_target_height = max(t.size(-2) for t in targets)
    max_target_width = max(t.size(-1) for t in targets)

    batch_size = len(inputs)
    num_channels = inputs[0].size(0)

    # Initialize tensors with zeros
    batch_inputs = torch.zeros((batch_size, num_channels, max_input_height, max_input_width), dtype=inputs[0].dtype)
    batch_targets = torch.zeros((batch_size, max_target_height, max_target_width), dtype=targets[0].dtype)

    for i in range(batch_size):
        input_tensor = inputs[i]
        target_tensor = targets[i]

        # Get shapes
        c, h_inp, w_inp = input_tensor.size()
        h_tar, w_tar = target_tensor.size()

        # Copy input_tensor into batch_inputs
        batch_inputs[i, :, :h_inp, :w_inp] = input_tensor

        # Copy target_tensor into batch_targets
        batch_targets[i, :h_tar, :w_tar] = target_tensor

        # Debugging statements
        logger.debug(f"Batch index {i}:")
        logger.debug(f"  Input tensor shape: {input_tensor.shape}")
        logger.debug(f"  Target tensor shape: {target_tensor.shape}")
        logger.debug(f"  Batch input shape: {batch_inputs[i].shape}")
        logger.debug(f"  Batch target shape: {batch_targets[i].shape}")

    return batch_inputs, batch_targets

# %%
# -----------------------------
# 9. Training GUI Class
# -----------------------------
# We have enhanced the training logic by introducing helper methods to modularize
# the CNN and GAN training steps. This approach improves code readability and maintainability.
# Additionally, we've added a method to display predicted vs. actual outputs after each epoch,
# allowing for a clearer visual understanding of the model's performance.

# %%
class TrainingGUI:
    """
    A Tkinter-based GUI for real-time training progress visualization with 3D metrics plotting, 
    data tree integration, and improved training loop modularity.

    Enhancements:
    - Helper functions for CNN and GAN training steps:
      train_cnn_batch(), train_discriminator_batch(), train_generator_batch()
    - display_sample_predictions() method to show predictions vs. actual targets.
    """

    def __init__(self, root, total_epochs, total_batches, model, train_loader, 
                 val_loader, eval_loader, device, data_tree, task_dict, generator, discriminator):
        """Initialize the Training GUI."""
        self.root = root
        self.total_epochs = total_epochs
        self.total_batches = total_batches
        self.model = model
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.eval_loader = eval_loader
        self.device = device
        self.data_tree = data_tree  # Data tree integration
        self.task_dict = task_dict  # Store task dictionary for training logic

        # GAN models
        self.generator = generator
        self.discriminator = discriminator

        # Initialize other required attributes
        self.queue = queue.Queue()
        self.stop_event = threading.Event()

        # Initialize data storage for plots
        self.loss_data = []
        self.val_loss_data = []
        self.acc_data = []
        self.prediction_distances = []

        # Set up the GUI
        self.setup_gui()
        self.root.after(100, self.process_queue)

    def setup_gui(self):
        """Set up the GUI components."""
        self.frame = tk.Frame(self.root)
        self.frame.pack(fill=tk.BOTH, expand=True)

        # Top Section for Labels
        self.label_frame = tk.Frame(self.frame)
        self.label_frame.pack(pady=10)

        self.epoch_label = tk.Label(self.label_frame, text=f"Epoch: 0/{self.total_epochs}", font=("Helvetica", 14))
        self.epoch_label.grid(row=0, column=0, padx=10)

        self.batch_label = tk.Label(self.label_frame, text=f"Batch: 0/{self.total_batches}", font=("Helvetica", 12))
        self.batch_label.grid(row=0, column=1, padx=10)

        self.loss_label = tk.Label(self.label_frame, text="Loss: 0.0000", font=("Helvetica", 12))
        self.loss_label.grid(row=0, column=2, padx=10)

        self.accuracy_label = tk.Label(self.label_frame, text="Accuracy: 0.0000", font=("Helvetica", 12))
        self.accuracy_label.grid(row=0, column=3, padx=10)

        # Data Tree Visualization Section
        self.tree_frame = tk.Frame(self.frame, width=300, height=400)
        self.tree_frame.pack(side=tk.LEFT, padx=10, pady=10, fill=tk.Y)

        self.tree_label = tk.Label(self.tree_frame, text="Data Tree", font=("Helvetica", 14))
        self.tree_label.pack()

        self.tree_canvas = tk.Canvas(self.tree_frame, width=300, height=400, bg='white')
        self.tree_canvas.pack()

        # Display the data tree
        self.display_data_tree()

        # Plot Section (2D + 3D)
        self.fig = plt.figure(figsize=(12, 6))

        # 3D Plot on the Left
        self.ax_3d = self.fig.add_subplot(121, projection='3d')
        self.ax_3d.set_xlabel('Epoch')
        self.ax_3d.set_ylabel('Accuracy')
        self.ax_3d.set_zlabel('Distance from Actual')

        # 2D Plot on the Right
        self.ax_2d = self.fig.add_subplot(122)
        self.line_loss, = self.ax_2d.plot([], [], label='Training Loss')
        self.line_val_loss, = self.ax_2d.plot([], [], label='Validation Loss')
        self.ax_2d.legend()

        self.canvas_plot = FigureCanvasTkAgg(self.fig, master=self.frame)
        self.canvas_plot.draw()
        self.canvas_plot.get_tk_widget().pack(side=tk.TOP, fill=tk.BOTH, expand=True)

        # Bottom Section for Control Buttons
        self.button_frame = tk.Frame(self.frame)
        self.button_frame.pack(pady=10)

        self.start_button = tk.Button(self.button_frame, text="Start Training", command=self.start_training)
        self.start_button.grid(row=0, column=0, padx=10)

        self.stop_button = tk.Button(self.button_frame, text="Stop Training", command=self.stop_training)
        self.stop_button.grid(row=0, column=1, padx=10)

        self.evaluate_button = tk.Button(self.button_frame, text="Evaluate Model", command=self.evaluate_model_button)
        self.evaluate_button.grid(row=0, column=2, padx=10)

    def display_data_tree(self):
        """Generate and display the data tree as an image."""
        try:
            # Render the tree to a PNG using anytree and Graphviz
            dot_file = "tree.dot"
            png_file = "tree.png"

            # Export to .dot file
            DotExporter(self.data_tree).to_dotfile(dot_file)
            logger.info(f"Tree exported to {dot_file}")

            # Convert .dot to .png using Graphviz
            result = os.system(f'dot -Tpng {dot_file} -o {png_file}')
            if result != 0:
                raise RuntimeError("Failed to generate PNG. Ensure Graphviz is installed and in PATH.")

            # Load and display the PNG image
            img = Image.open(png_file)
            img = img.resize((300, 400), Image.LANCZOS)
            img_tk = ImageTk.PhotoImage(img)

            # Display the image in the canvas
            self.tree_canvas.create_image(0, 0, anchor=tk.NW, image=img_tk)
            self.tree_canvas.image = img_tk  # Keep reference to avoid garbage collection
            logger.info("Tree visualization displayed successfully.")

        except Exception as e:
            logger.exception("Failed to display the data tree.")
            tk.messagebox.showerror("Tree Display Error", f"Error: {e}")

    def process_queue(self):
        """Process the queue for thread-safe GUI updates."""
        while not self.queue.empty():
            message = self.queue.get()
            if isinstance(message, dict):
                self.update_gui(message)
        self.root.after(100, self.process_queue)

    def update_gui(self, data):
        """Update the GUI with real-time training and validation metrics."""
        try:
            if 'batch' in data:
                # Update batch-level metrics in the GUI
                self.batch_label.config(text=f"Batch: {data['batch']}/{self.total_batches}")
                self.loss_label.config(text=f"Loss: {data['loss']:.4f}")
                self.accuracy_label.config(text=f"Accuracy: {data.get('accuracy', 0.0):.4f}")

                # Append new batch data to the 2D plot lists
                self.loss_data.append(data['loss'])
                self.acc_data.append(data.get('accuracy', 0.0))

                # Update the 2D plot
                batches = list(range(1, len(self.loss_data) + 1))
                self.line_loss.set_data(batches, self.loss_data)
                self.line_val_loss.set_data(batches, self.acc_data)

                # Adjust the axes and redraw
                self.ax_2d.relim()
                self.ax_2d.autoscale_view()
                self.canvas_plot.draw()

            elif 'epoch' in data:
                # Update epoch-level metrics
                self.epoch_label.config(text=f"Epoch: {data['epoch']}/{self.total_epochs}")

                # Calculate prediction error distance
                predicted = np.array(data.get('guesses', []))
                actual = np.array(data.get('actuals', []))

                if predicted.size == 0 or actual.size == 0:
                    distance = float('nan')
                elif predicted.shape != actual.shape:
                    distance = float('nan')
                else:
                    distance = np.abs(predicted - actual).mean()

                distance = 0.0 if np.isnan(distance) else distance
                self.prediction_distances.append(distance)

                # Update the 3D plot
                epochs = list(range(1, len(self.prediction_distances) + 1))
                self.ax_3d.clear()
                self.ax_3d.set_xlabel('Epoch')
                self.ax_3d.set_ylabel('Accuracy')
                self.ax_3d.set_zlabel('Distance from Actual')
                self.ax_3d.set_title('3D Prediction Error vs Accuracy')
                self.ax_3d.scatter(epochs, self.acc_data, self.prediction_distances, label='Error vs Accuracy', color='green')
                self.ax_3d.legend()
                self.canvas_plot.draw()

                # If flagged, display sample predictions
                if 'show_predictions' in data and data['show_predictions']:
                    predictions_np = data['guesses'].numpy()
                    actuals_np = data['actuals'].numpy()
                    self.display_sample_predictions(predictions_np, actuals_np)

        except Exception as e:
            logger.exception("An error occurred while updating the GUI.")
            messagebox.showerror("Error", f"An error occurred: {e}")

    def display_sample_predictions(self, predictions, targets):
        """
        Displays model predictions versus actual targets in a separate Tk window.

        Args:
            predictions (numpy.ndarray): Array of predicted grids.
            targets (numpy.ndarray): Array of actual target grids.

        Each pair of prediction vs. actual is displayed side-by-side to facilitate comparison.
        """
        window = tk.Toplevel(self.root)
        window.title("Sample Predictions vs Actual")

        for i, (pred, tgt) in enumerate(zip(predictions, targets)):
            pred_img = grid_to_image(pred, color_map)
            tgt_img = grid_to_image(tgt, color_map)

            pred_tk = ImageTk.PhotoImage(pred_img)
            tgt_tk = ImageTk.PhotoImage(tgt_img)

            frame = tk.Frame(window)
            frame.pack(side=tk.TOP, pady=5)

            pred_label = tk.Label(frame, image=pred_tk, text="Prediction", compound=tk.TOP)
            pred_label.image = pred_tk
            pred_label.pack(side=tk.LEFT, padx=10)

            tgt_label = tk.Label(frame, image=tgt_tk, text="Actual", compound=tk.TOP)
            tgt_label.image = tgt_tk
            tgt_label.pack(side=tk.LEFT, padx=10)

    def start_training(self):
        """Start training in a new thread."""
        self.stop_event.clear()
        threading.Thread(target=self.train_thread, daemon=True).start()

    def stop_training(self):
        """Stop the training process."""
        self.stop_event.set()

    def train_cnn_batch(self, inputs_cnn, targets_cnn, optimizer_cnn, scaler_cnn, criterion_cnn):
        """
        Train the CNN model on a single batch of data.

        Args:
            inputs_cnn (torch.Tensor): Input batch of images.
            targets_cnn (torch.Tensor): Corresponding target grids.
            optimizer_cnn (torch.optim.Optimizer): CNN optimizer.
            scaler_cnn (torch.cuda.amp.GradScaler or None): Grad scaler for mixed-precision.
            criterion_cnn (nn.Module): Loss function (e.g., CrossEntropyLoss).

        Returns:
            tuple: (batch_loss, batch_accuracy, num_pixels)
        """
        optimizer_cnn.zero_grad()

        if self.device.type == 'cuda' and scaler_cnn is not None:
            with torch.cuda.amp.autocast(enabled=True):
                outputs = self.model(inputs_cnn)
                outputs = F.interpolate(outputs, size=targets_cnn.shape[1:], mode='bilinear', align_corners=False)
                loss = criterion_cnn(outputs, targets_cnn)
            scaler_cnn.scale(loss).backward()
            scaler_cnn.step(optimizer_cnn)
            scaler_cnn.update()
        else:
            outputs = self.model(inputs_cnn)
            outputs = F.interpolate(outputs, size=targets_cnn.shape[1:], mode='bilinear', align_corners=False)
            loss = criterion_cnn(outputs, targets_cnn)
            loss.backward()
            optimizer_cnn.step()

        batch_loss = loss.item()
        _, predicted = outputs.max(1)
        correct_predictions = predicted.eq(targets_cnn).sum().item()
        batch_accuracy = 100.0 * correct_predictions / targets_cnn.numel()

        return batch_loss, batch_accuracy, targets_cnn.numel()

    def train_discriminator_batch(self, real_images, optimizer_disc, scaler_gan, criterion_gan):
        """
        Train the Discriminator on a batch of real and generated images.

        Args:
            real_images (torch.Tensor): A batch of real images.
            optimizer_disc (torch.optim.Optimizer): Discriminator optimizer.
            scaler_gan (torch.cuda.amp.GradScaler or None): Grad scaler for mixed precision.
            criterion_gan (nn.Module): GAN loss function (e.g., BCELoss).

        Returns:
            float: Discriminator loss for this batch.
        """
        batch_size = real_images.size(0)
        label_real = torch.ones(batch_size, device=self.device)
        label_fake = torch.zeros(batch_size, device=self.device)

        # One-hot encode and normalize real images
        inputs_one_hot = torch.nn.functional.one_hot(real_images.squeeze(1).long(), num_classes=NUM_CLASSES)
        inputs_one_hot = inputs_one_hot.permute(0, 3, 1, 2).float()
        inputs_one_hot = (inputs_one_hot - 0.5) * 2

        optimizer_disc.zero_grad()

        if self.device.type == 'cuda' and scaler_gan is not None:
            with torch.cuda.amp.autocast(enabled=True):
                # Real images
                output_real = self.discriminator(inputs_one_hot)
                d_loss_real = criterion_gan(output_real, label_real)

                # Fake images
                noise = torch.randn(batch_size, 100, device=self.device)
                fake_images = self.generator(noise)
                output_fake = self.discriminator(fake_images.detach())
                d_loss_fake = criterion_gan(output_fake, label_fake)

                d_loss = d_loss_real + d_loss_fake

            scaler_gan.scale(d_loss).backward()
            scaler_gan.step(optimizer_disc)
            scaler_gan.update()
        else:
            output_real = self.discriminator(inputs_one_hot)
            d_loss_real = criterion_gan(output_real, label_real)

            noise = torch.randn(batch_size, 100, device=self.device)
            fake_images = self.generator(noise)
            output_fake = self.discriminator(fake_images.detach())
            d_loss_fake = criterion_gan(output_fake, label_fake)

            d_loss = d_loss_real + d_loss_fake
            d_loss.backward()
            optimizer_disc.step()

        return d_loss.item()

    def train_generator_batch(self, batch_size, optimizer_gen, scaler_gan, criterion_gan):
        """
        Train the Generator for one batch, making it produce images that can fool the Discriminator.

        Args:
            batch_size (int): Number of samples in the batch.
            optimizer_gen (torch.optim.Optimizer): Generator optimizer.
            scaler_gan (torch.cuda.amp.GradScaler or None): Grad scaler for mixed precision.
            criterion_gan (nn.Module): GAN loss function.

        Returns:
            float: Generator loss for this batch.
        """
        optimizer_gen.zero_grad()
        noise = torch.randn(batch_size, 100, device=self.device)

        if self.device.type == 'cuda' and scaler_gan is not None:
            with torch.cuda.amp.autocast(enabled=True):
                fake_images = self.generator(noise)
                output_fake = self.discriminator(fake_images)
                g_loss = criterion_gan(output_fake, torch.ones(batch_size, device=self.device))
            scaler_gan.scale(g_loss).backward()
            scaler_gan.step(optimizer_gen)
            scaler_gan.update()
        else:
            fake_images = self.generator(noise)
            output_fake = self.discriminator(fake_images)
            g_loss = criterion_gan(output_fake, torch.ones(batch_size, device=self.device))
            g_loss.backward()
            optimizer_gen.step()

        return g_loss.item()

    def train_thread(self):
        """Training logic executed in a separate thread to avoid blocking the GUI."""
        logger.info("Training thread started.")

        # Optimizer, scheduler, and criterion setup for CNN
        optimizer_cnn = torch.optim.AdamW(self.model.parameters(), lr=0.01, weight_decay=1e-4)
        scheduler_cnn = torch.optim.lr_scheduler.StepLR(optimizer_cnn, step_size=10, gamma=0.1)
        criterion_cnn = nn.CrossEntropyLoss()

        # Define GAN optimizers and criterion
        optimizer_gen = torch.optim.Adam(self.generator.parameters(), lr=0.0002, betas=(0.5, 0.999))
        optimizer_disc = torch.optim.Adam(self.discriminator.parameters(), lr=0.0002, betas=(0.5, 0.999))
        criterion_gan = nn.BCELoss()

        # Mixed precision scaler (if using CUDA)
        scaler_cnn = torch.cuda.amp.GradScaler() if self.device.type == 'cuda' else None
        scaler_gan = torch.cuda.amp.GradScaler() if self.device.type == 'cuda' else None

        # Loop over epochs
        for epoch in range(self.total_epochs):
            if self.stop_event.is_set():
                logger.info("Training stopped by user.")
                break
            logger.info(f"Starting epoch {epoch + 1}/{self.total_epochs}.")
            self.model.train()  # Set the CNN model in training mode
            self.generator.train()
            self.discriminator.train()

            running_loss = 0.0
            correct = 0
            total = 0

            # Loop over batches for CNN training
            for batch_idx, (inputs, targets) in enumerate(self.train_loader, 1):
                if self.stop_event.is_set():
                    logger.info("Training stopped by user.")
                    break
                try:
                    inputs_cnn, targets_cnn = inputs.to(self.device), targets.to(self.device)
                    batch_loss, batch_accuracy, num_pixels = self.train_cnn_batch(
                        inputs_cnn, targets_cnn, optimizer_cnn, scaler_cnn, criterion_cnn
                    )
                    running_loss += batch_loss * inputs_cnn.size(0)
                    correct += int(batch_accuracy/100.0 * num_pixels)
                    total += num_pixels

                    # Update GUI every 10 batches or at end of epoch
                    if batch_idx % 10 == 0 or batch_idx == len(self.train_loader):
                        gui_batch_loss = running_loss / total
                        gui_batch_accuracy = 100.0 * correct / total
                        self.queue.put({
                            'batch': batch_idx,
                            'loss': gui_batch_loss,
                            'accuracy': gui_batch_accuracy
                        })

                except Exception as e:
                    logger.exception(f"Error in CNN batch {batch_idx}: {e}")
                    continue

            # GAN training loop
            for batch_idx, (inputs_gan, _) in enumerate(self.train_loader, 1):
                if self.stop_event.is_set():
                    logger.info("Training stopped by user.")
                    break
                try:
                    real_images = inputs_gan.to(self.device)
                    batch_size = real_images.size(0)

                    # Train Discriminator
                    d_loss = self.train_discriminator_batch(real_images, optimizer_disc, scaler_gan, criterion_gan)

                    # Train Generator
                    g_loss = self.train_generator_batch(batch_size, optimizer_gen, scaler_gan, criterion_gan)

                    # Log GAN losses periodically
                    if batch_idx % 50 == 0:
                        logger.info(
                            f"[Epoch {epoch+1}/{self.total_epochs}] [GAN Batch {batch_idx}/{len(self.train_loader)}] "
                            f"[D loss: {d_loss:.4f}] [G loss: {g_loss:.4f}]"
                        )

                except Exception as e:
                    logger.exception(f"Error in GAN batch {batch_idx}: {e}")
                    continue

            # Sample predictions for visualization
            try:
                sample_inputs, sample_targets = next(iter(self.val_loader))  # validation sample
                sample_inputs = sample_inputs.to(self.device)
                with torch.no_grad():
                    sample_outputs = self.model(sample_inputs)
                    sample_outputs = F.interpolate(sample_outputs, size=sample_targets.shape[1:], mode='bilinear', align_corners=False)
                    _, sample_predictions = sample_outputs.max(1)
            except StopIteration:
                logger.warning("Validation loader is empty.")
                sample_predictions = torch.tensor([])
                sample_targets = torch.tensor([])

            # Send epoch updates, including show_predictions flag
            self.queue.put({
                'epoch': epoch + 1,
                'loss': running_loss / total if total > 0 else 0.0,
                'accuracy': 100.0 * correct / total if total > 0 else 0.0,
                'guesses': sample_predictions.cpu(),
                'actuals': sample_targets.cpu(),
                'show_predictions': True  # Trigger sample predictions display
            })

            # Scheduler step
            scheduler_cnn.step()

        logger.info("Training completed.")
        self.queue.put({'status': 'Training Completed'})

    def train_batch(self, batch_idx, inputs, targets, optimizer, scaler, criterion):
        """Train a single batch (Deprecated: now replaced by train_cnn_batch())."""
        # This method is now redundant since we introduced train_cnn_batch().
        # It remains here only if you need legacy fallback or additional tasks.
        inputs, targets = inputs.to(self.device), targets.to(self.device)

        optimizer.zero_grad()

        if self.device.type == 'cuda' and scaler is not None:
            with torch.cuda.amp.autocast(enabled=True):
                outputs = self.model(inputs)
                outputs = F.interpolate(outputs, size=targets.shape[1:], mode='bilinear', align_corners=False)
                loss = criterion(outputs, targets)
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
        else:
            outputs = self.model(inputs)
            outputs = F.interpolate(outputs, size=targets.shape[1:], mode='bilinear', align_corners=False)
            loss = criterion(outputs, targets)
            loss.backward()
            optimizer.step()

        batch_loss = loss.item()
        _, predicted = outputs.max(1)
        correct_predictions = predicted.eq(targets).sum().item()
        batch_accuracy = 100.0 * correct_predictions / targets.numel()

        return batch_loss, batch_accuracy, targets.numel()

    def evaluate_model_button(self):
        """Evaluate the model in a new thread."""
        threading.Thread(target=self.evaluate_model, daemon=True).start()

    def evaluate_model(self):
        """Evaluate the model."""
        avg_loss, accuracy = evaluate_model(self.model, self.val_loader, self.device)
        messagebox.showinfo("Evaluation", f"Validation Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")

# %%
#10. Training Function with GUI Integration
#In this section, we define the training function that integrates with the GUI. This function will handle the training process 
#and update the GUI in real-time with the latest metrics and progress. 
#It ensures that the training logic is separated from the GUI logic, maintaining clean code organization.

# %%
# -----------------------------
# 10. Training Function with GUI Integration
# -----------------------------

def train_model_with_gui(model, train_loader, val_loader, device, gui):
    """Train the model and update the GUI in real-time."""
    try:
        # Start the GUI training display
        gui.start_training()

    except Exception as e:
        logger.exception(f"Training failed: {e}")
        gui.queue.put({'error': str(e)})  # Inform the GUI about the error

# %%
#11. Evaluation Function
#Here, we define the evaluation function that assesses the model's performance on a test dataset. 
#It computes metrics such as average loss and accuracy, which are essential for understanding how well the model generalizes to unseen data. 
#This function can be called during or after training to monitor progress.

# %%
# -----------------------------
# 11. Evaluation Function
# -----------------------------

def evaluate_model(model, test_loader, device='cpu'):
    """
    Evaluates the model on the test dataset.

    Args:
        model (nn.Module): Trained model.
        test_loader (DataLoader): DataLoader for the test dataset.
        device (str): Device to run evaluation on.

    Returns:
        tuple: (average_loss, accuracy)
    """
    criterion = nn.CrossEntropyLoss()  # Loss function
    model.to(device)  # Move model to the appropriate device
    model.eval()  # Set the model to evaluation mode

    total_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, targets in test_loader:
            inputs = inputs.to(device, non_blocking=True)
            targets = targets.to(device, non_blocking=True)

            # Forward pass
            outputs = model(inputs)
            # Resize outputs to match targets
            outputs = F.interpolate(outputs, size=targets.shape[1:], mode='bilinear', align_corners=False)

            # Calculate loss
            loss = criterion(outputs, targets)
            total_loss += loss.item() * inputs.size(0)  # Accumulate weighted loss

            # Calculate accuracy
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == targets).sum().item()
            total += targets.numel()

    # Calculate average loss and accuracy
    avg_loss = total_loss / len(test_loader.dataset)
    accuracy = correct / total

    logger.info(f"Test Loss: {avg_loss:.4f}, Test Accuracy: {accuracy:.4f}")
    return avg_loss, accuracy

# %%
#12. Traverse and Debug Function
#This utility function helps in traversing the data tree for debugging purposes.
#It logs node details with reduced verbosity to avoid overwhelming the console with information, especially when dealing with large datasets.

# %%
# -----------------------------
# 12. Traverse and Debug Function
# -----------------------------

def traverse_and_debug(node):
    """Traverse the tree and log node details with reduced verbosity."""
    # Limit logging to fewer nodes
    if hasattr(node, "name"):
        grid_shape = getattr(node, 'embedding', None)
        grid_shape = grid_shape.shape if grid_shape is not None else 'Missing'
        logger.debug(f"Node: {node.name}, Grid Shape: {grid_shape}")
    if len(node.children) > 10:  # Avoid excessive logging if many children exist
        logger.warning(f"Node '{node.name}' has too many children, skipping further logs...")
        return
    for child in node.children:
        traverse_and_debug(child)

# %%
#13. Main Workflow with Modifications
#In the main function, we orchestrate the entire workflow of loading data, initializing models, 
#setting up the GUI, and starting the training process. We use progress bars to provide feedback during data loading and model initialization. 
#Exception handling ensures that any issues are logged and the program exits gracefully.

# %%
# -----------------------------
# 13. Main Workflow with Modifications
# -----------------------------

def main():
    # Detect device
    device = get_device()

    # Initialize the progress bar
    progress_bar = tqdm(total=100, desc="Loading Data", unit="%", leave=True)

    try:
        # Load ARC data
        arc_data = load_arc_data()
        progress_bar.update(20)

        # Extract and reshape grid pairs
        train_grid_pairs = flatten_and_reshape(
            arc_data.get("arc-agi_training-challenges", {})
        )
        eval_grid_pairs = flatten_and_reshape(
            arc_data.get("arc-agi_evaluation-challenges", {})
        )
        progress_bar.update(30)

        # Build the data tree and retrieve the task dictionary
        root_node, task_dict = build_data_tree(train_grid_pairs)
        traverse_and_debug(root_node)
        progress_bar.update(20)

        # Log the task dictionary
        logger.info(f"Task dictionary initialized with {len(task_dict)} tasks:")
        for task_id, task_data in task_dict.items():
            logger.info(
                f"Task ID: {task_id}, Node: {task_data['task_node'].name}, "
                f"Grid Shape: {task_data['grids'][0].shape}"
            )

        # Initialize DataLoaders and models
        train_dataset = AugmentedARCDataset(train_grid_pairs, augment=False)
        val_dataset = AugmentedARCDataset(eval_grid_pairs, augment=False)

        train_loader = DataLoader(
            train_dataset,
            batch_size=4,  # Reduce batch size if you encounter memory issues
            shuffle=True,
            num_workers=0,
            pin_memory=True,
            collate_fn=collate_fn  # Use the custom collate function
        )
        val_loader = DataLoader(
            val_dataset,
            batch_size=4,
            shuffle=False,
            num_workers=0,
            pin_memory=True,
            collate_fn=collate_fn
        )

        # Initialize the CNN model
        model = CNNGridMapper(num_classes=NUM_CLASSES).to(device)
        if torch.cuda.device_count() > 1:
            model = nn.DataParallel(model)
        logger.info("CNN Model initialized successfully.")

        # Initialize GAN models
        generator = Generator(latent_dim=100, output_channels=NUM_CLASSES, grid_size=(FIXED_HEIGHT, FIXED_WIDTH)).to(device)
        discriminator = Discriminator(input_channels=NUM_CLASSES, grid_size=(FIXED_HEIGHT, FIXED_WIDTH)).to(device)
        if torch.cuda.device_count() > 1:
            generator = nn.DataParallel(generator)
            discriminator = nn.DataParallel(discriminator)
        logger.info("GAN Models initialized successfully.")

    except Exception as e:
        logger.exception(f"Data loading or model initialization failed: {e}")
        progress_bar.close()
        return

    progress_bar.close()

    # Initialize and start the GUI
    root_window = tk.Tk()
    root_window.title("Training Progress Visualization")
    gui = TrainingGUI(
        root_window, total_epochs=10, total_batches=len(train_loader),
        model=model, train_loader=train_loader, val_loader=val_loader,
        eval_loader=None, device=device, data_tree=root_node, task_dict=task_dict,
        generator=generator, discriminator=discriminator  # Pass GAN models
    )

    # Start the training thread
    training_thread = threading.Thread(
        target=train_model_with_gui, args=(model, train_loader, val_loader, device, gui)
    )
    training_thread.daemon = True
    training_thread.start()

    # Start the GUI main loop
    root_window.mainloop()


if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:Using CPU as fallback.
# Loading Data:   0%|                                                                             | 0/100 [00:00<?, ?%/s]
# INFO:__main__:Loaded data from arc-agi_training_challenges.json.
# INFO:__main__:Loaded data from arc-agi_evaluation_challenges.json.
# INFO:__main__:Loaded data from arc-agi_training_solutions.json.
# INFO:__main__:Loaded data from arc-agi_evaluation_solutions.json.
# Loading Data:  20%|█████████████▍                                                     | 20/100 [00:00<00:00, 127.68%/s]
# INFO:__main__:Parsing task 007bbfb7...
# INFO:__main__:Parsing task 00d62c1b...
# INFO:__main__:Parsing task 017c7c7b...
# INFO:__main__:Parsing task 025d127b...
# INFO:__main__:Parsing task 045e512c...
# INFO:__main__:Parsing task 0520fde7...
# INFO:__main__:Parsing task 05269061...
# INFO:__main__:Parsing task 05f2a901...
# INFO:__main__:Parsing task 06df4c85...
# INFO:__main__:Parsing task 08ed6ac7...
# INFO:__main__:Parsing task 09629e4f...
# INFO:__main__:Parsing task 0962bcdd...
# INFO:__main__:Parsing task 0a938d79...
# INFO:__main__:Parsing task 0b148d64...
# INFO:__main__:Parsing task 0ca9ddb6...
# INFO:__main__:Parsing task 0d3d703e...
# INFO:__main__:Parsing task 0dfd9992...
# INFO:__main__:Parsing task 0e206a2e...
# INFO:__main__:Parsing task 10fcaaa3...
# INFO:__main__:Parsing task 11852cab...
# INFO:__main__:Parsing task 1190e5a7...
# INFO:__main__:Parsing task 137eaa0f...
# INFO:__main__:Parsing task 150deff5...
# INFO:__main__:Parsing task 178fcbfb...
# INFO:__main__:Parsing task 1a07d186...
# INFO:__main__:Parsing task 1b2d62fb...
# INFO:__main__:Parsing task 1b60fb0c...
# INFO:__main__:Parsing task 1bfc4729...
# INFO:__main__:Parsing task 1c786137...
# INFO:__main__:Parsing task 1caeab9d...
# INFO:__main__:Parsing task 1cf80156...
# INFO:__main__:Parsing task 1e0a9b12...
# INFO:__main__:Parsing task 1e32b0e9...
# INFO:__main__:Parsing task 1f0c79e5...
# INFO:__main__:Parsing task 1f642eb9...
# INFO:__main__:Parsing task 1f85a75f...
# INFO:__main__:Parsing task 1f876c06...
# INFO:__main__:Parsing task 1fad071e...
# INFO:__main__:Parsing task 2013d3e2...
# INFO:__main__:Parsing task 2204b7a8...
# INFO:__main__:Parsing task 22168020...
# INFO:__main__:Parsing task 22233c11...
# INFO:__main__:Parsing task 2281f1f4...
# INFO:__main__:Parsing task 228f6490...
# INFO:__main__:Parsing task 22eb0ac0...
# INFO:__main__:Parsing task 234bbc79...
# INFO:__main__:Parsing task 23581191...
# INFO:__main__:Parsing task 239be575...
# INFO:__main__:Parsing task 23b5c85d...
# INFO:__main__:Parsing task 253bf280...
# INFO:__main__:Parsing task 25d487eb...
# INFO:__main__:Parsing task 25d8a9c8...
# INFO:__main__:Parsing task 25ff71a9...
# INFO:__main__:Parsing task 264363fd...
# INFO:__main__:Parsing task 272f95fa...
# INFO:__main__:Parsing task 27a28665...
# INFO:__main__:Parsing task 28bf18c6...
# INFO:__main__:Parsing task 28e73c20...
# INFO:__main__:Parsing task 29623171...
# INFO:__main__:Parsing task 29c11459...
# INFO:__main__:Parsing task 29ec7d0e...
# INFO:__main__:Parsing task 2bcee788...
# INFO:__main__:Parsing task 2bee17df...
# INFO:__main__:Parsing task 2c608aff...
# INFO:__main__:Parsing task 2dc579da...
# INFO:__main__:Parsing task 2dd70a9a...
# INFO:__main__:Parsing task 2dee498d...
# INFO:__main__:Parsing task 31aa019c...
# INFO:__main__:Parsing task 321b1fc6...
# INFO:__main__:Parsing task 32597951...
# INFO:__main__:Parsing task 3345333e...
# INFO:__main__:Parsing task 3428a4f5...
# INFO:__main__:Parsing task 3618c87e...
# INFO:__main__:Parsing task 3631a71a...
# INFO:__main__:Parsing task 363442ee...
# INFO:__main__:Parsing task 36d67576...
# INFO:__main__:Parsing task 36fdfd69...
# INFO:__main__:Parsing task 3906de3d...
# INFO:__main__:Parsing task 39a8645d...
# INFO:__main__:Parsing task 39e1d7f9...
# INFO:__main__:Parsing task 3aa6fb7a...
# INFO:__main__:Parsing task 3ac3eb23...
# INFO:__main__:Parsing task 3af2c5a8...
# INFO:__main__:Parsing task 3bd67248...
# INFO:__main__:Parsing task 3bdb4ada...
# INFO:__main__:Parsing task 3befdf3e...
# INFO:__main__:Parsing task 3c9b0459...
# INFO:__main__:Parsing task 3de23699...
# INFO:__main__:Parsing task 3e980e27...
# INFO:__main__:Parsing task 3eda0437...
# INFO:__main__:Parsing task 3f7978a0...
# INFO:__main__:Parsing task 40853293...
# INFO:__main__:Parsing task 4093f84a...
# INFO:__main__:Parsing task 41e4d17e...
# INFO:__main__:Parsing task 4258a5f9...
# INFO:__main__:Parsing task 4290ef0e...
# INFO:__main__:Parsing task 42a50994...
# INFO:__main__:Parsing task 4347f46a...
# INFO:__main__:Parsing task 444801d8...
# INFO:__main__:Parsing task 445eab21...
# INFO:__main__:Parsing task 447fd412...
# INFO:__main__:Parsing task 44d8ac46...
# INFO:__main__:Parsing task 44f52bb0...
# INFO:__main__:Parsing task 4522001f...
# INFO:__main__:Parsing task 4612dd53...
# INFO:__main__:Parsing task 46442a0e...
# INFO:__main__:Parsing task 469497ad...
# INFO:__main__:Parsing task 46f33fce...
# INFO:__main__:Parsing task 47c1f68c...
# INFO:__main__:Parsing task 484b58aa...
# INFO:__main__:Parsing task 48d8fb45...
# INFO:__main__:Parsing task 4938f0c2...
# INFO:__main__:Parsing task 496994bd...
# INFO:__main__:Parsing task 49d1d64f...
# INFO:__main__:Parsing task 4be741c5...
# INFO:__main__:Parsing task 4c4377d9...
# INFO:__main__:Parsing task 4c5c2cf0...
# INFO:__main__:Parsing task 50846271...
# INFO:__main__:Parsing task 508bd3b6...
# INFO:__main__:Parsing task 50cb2852...
# INFO:__main__:Parsing task 5117e062...
# INFO:__main__:Parsing task 5168d44c...
# INFO:__main__:Parsing task 539a4f51...
# INFO:__main__:Parsing task 53b68214...
# INFO:__main__:Parsing task 543a7ed5...
# INFO:__main__:Parsing task 54d82841...
# INFO:__main__:Parsing task 54d9e175...
# INFO:__main__:Parsing task 5521c0d9...
# INFO:__main__:Parsing task 5582e5ca...
# INFO:__main__:Parsing task 5614dbcf...
# INFO:__main__:Parsing task 56dc2b01...
# INFO:__main__:Parsing task 56ff96f3...
# INFO:__main__:Parsing task 57aa92db...
# INFO:__main__:Parsing task 5ad4f10b...
# INFO:__main__:Parsing task 5bd6f4ac...
# INFO:__main__:Parsing task 5c0a986e...
# INFO:__main__:Parsing task 5c2c9af4...
# INFO:__main__:Parsing task 5daaa586...
# INFO:__main__:Parsing task 60b61512...
# INFO:__main__:Parsing task 6150a2bd...
# INFO:__main__:Parsing task 623ea044...
# INFO:__main__:Parsing task 62c24649...
# INFO:__main__:Parsing task 63613498...
# INFO:__main__:Parsing task 6430c8c4...
# INFO:__main__:Parsing task 6455b5f5...
# INFO:__main__:Parsing task 662c240a...
# INFO:__main__:Parsing task 67385a82...
# INFO:__main__:Parsing task 673ef223...
# INFO:__main__:Parsing task 6773b310...
# INFO:__main__:Parsing task 67a3c6ac...
# INFO:__main__:Parsing task 67a423a3...
# INFO:__main__:Parsing task 67e8384a...
# INFO:__main__:Parsing task 681b3aeb...
# INFO:__main__:Parsing task 6855a6e4...
# INFO:__main__:Parsing task 68b16354...
# INFO:__main__:Parsing task 694f12f3...
# INFO:__main__:Parsing task 6a1e5592...
# INFO:__main__:Parsing task 6aa20dc0...
# INFO:__main__:Parsing task 6b9890af...
# INFO:__main__:Parsing task 6c434453...
# INFO:__main__:Parsing task 6cdd2623...
# INFO:__main__:Parsing task 6cf79266...
# INFO:__main__:Parsing task 6d0160f0...
# INFO:__main__:Parsing task 6d0aefbc...
# INFO:__main__:Parsing task 6d58a25d...
# INFO:__main__:Parsing task 6d75e8bb...
# INFO:__main__:Parsing task 6e02f1e3...
# INFO:__main__:Parsing task 6e19193c...
# INFO:__main__:Parsing task 6e82a1ae...
# INFO:__main__:Parsing task 6ecd11f4...
# INFO:__main__:Parsing task 6f8cd79b...
# INFO:__main__:Parsing task 6fa7a44f...
# INFO:__main__:Parsing task 72322fa7...
# INFO:__main__:Parsing task 72ca375d...
# INFO:__main__:Parsing task 73251a56...
# INFO:__main__:Parsing task 7447852a...
# INFO:__main__:Parsing task 7468f01a...
# INFO:__main__:Parsing task 746b3537...
# INFO:__main__:Parsing task 74dd1130...
# INFO:__main__:Parsing task 75b8110e...
# INFO:__main__:Parsing task 760b3cac...
# INFO:__main__:Parsing task 776ffc46...
# INFO:__main__:Parsing task 77fdfe62...
# INFO:__main__:Parsing task 780d0b14...
# INFO:__main__:Parsing task 7837ac64...
# INFO:__main__:Parsing task 794b24be...
# INFO:__main__:Parsing task 7b6016b9...
# INFO:__main__:Parsing task 7b7f7511...
# INFO:__main__:Parsing task 7c008303...
# INFO:__main__:Parsing task 7ddcd7ec...
# INFO:__main__:Parsing task 7df24a62...
# INFO:__main__:Parsing task 7e0986d6...
# INFO:__main__:Parsing task 7f4411dc...
# INFO:__main__:Parsing task 7fe24cdd...
# INFO:__main__:Parsing task 80af3007...
# INFO:__main__:Parsing task 810b9b61...
# INFO:__main__:Parsing task 82819916...
# INFO:__main__:Parsing task 83302e8f...
# INFO:__main__:Parsing task 834ec97d...
# INFO:__main__:Parsing task 8403a5d5...
# INFO:__main__:Parsing task 846bdb03...
# INFO:__main__:Parsing task 855e0971...
# INFO:__main__:Parsing task 85c4e7cd...
# INFO:__main__:Parsing task 868de0fa...
# INFO:__main__:Parsing task 8731374e...
# INFO:__main__:Parsing task 88a10436...
# INFO:__main__:Parsing task 88a62173...
# INFO:__main__:Parsing task 890034e9...
# INFO:__main__:Parsing task 8a004b2b...
# INFO:__main__:Parsing task 8be77c9e...
# INFO:__main__:Parsing task 8d5021e8...
# INFO:__main__:Parsing task 8d510a79...
# INFO:__main__:Parsing task 8e1813be...
# INFO:__main__:Parsing task 8e5a5113...
# INFO:__main__:Parsing task 8eb1be9a...
# INFO:__main__:Parsing task 8efcae92...
# INFO:__main__:Parsing task 8f2ea7aa...
# INFO:__main__:Parsing task 90c28cc7...
# INFO:__main__:Parsing task 90f3ed37...
# INFO:__main__:Parsing task 913fb3ed...
# INFO:__main__:Parsing task 91413438...
# INFO:__main__:Parsing task 91714a58...
# INFO:__main__:Parsing task 9172f3a0...
# INFO:__main__:Parsing task 928ad970...
# INFO:__main__:Parsing task 93b581b8...
# INFO:__main__:Parsing task 941d9a10...
# INFO:__main__:Parsing task 94f9d214...
# INFO:__main__:Parsing task 952a094c...
# INFO:__main__:Parsing task 9565186b...
# INFO:__main__:Parsing task 95990924...
# INFO:__main__:Parsing task 963e52fc...
# INFO:__main__:Parsing task 97999447...
# INFO:__main__:Parsing task 97a05b5b...
# INFO:__main__:Parsing task 98cf29f8...
# INFO:__main__:Parsing task 995c5fa3...
# INFO:__main__:Parsing task 99b1bc43...
# INFO:__main__:Parsing task 99fa7670...
# INFO:__main__:Parsing task 9aec4887...
# INFO:__main__:Parsing task 9af7a82c...
# INFO:__main__:Parsing task 9d9215db...
# INFO:__main__:Parsing task 9dfd6313...
# INFO:__main__:Parsing task 9ecd008a...
# INFO:__main__:Parsing task 9edfc990...
# INFO:__main__:Parsing task 9f236235...
# INFO:__main__:Parsing task a1570a43...
# INFO:__main__:Parsing task a2fd1cf0...
# INFO:__main__:Parsing task a3325580...
# INFO:__main__:Parsing task a3df8b1e...
# INFO:__main__:Parsing task a416b8f3...
# INFO:__main__:Parsing task a48eeaf7...
# INFO:__main__:Parsing task a5313dff...
# INFO:__main__:Parsing task a5f85a15...
# INFO:__main__:Parsing task a61ba2ce...
# INFO:__main__:Parsing task a61f2674...
# INFO:__main__:Parsing task a64e4611...
# INFO:__main__:Parsing task a65b410d...
# INFO:__main__:Parsing task a68b268e...
# INFO:__main__:Parsing task a699fb00...
# INFO:__main__:Parsing task a740d043...
# INFO:__main__:Parsing task a78176bb...
# INFO:__main__:Parsing task a79310a0...
# INFO:__main__:Parsing task a85d4709...
# INFO:__main__:Parsing task a87f7484...
# INFO:__main__:Parsing task a8c38be5...
# INFO:__main__:Parsing task a8d7556c...
# INFO:__main__:Parsing task a9f96cdd...
# INFO:__main__:Parsing task aabf363d...
# INFO:__main__:Parsing task aba27056...
# INFO:__main__:Parsing task ac0a08a4...
# INFO:__main__:Parsing task ae3edfdc...
# INFO:__main__:Parsing task ae4f1146...
# INFO:__main__:Parsing task aedd82e4...
# INFO:__main__:Parsing task af902bf9...
# INFO:__main__:Parsing task b0c4d837...
# INFO:__main__:Parsing task b190f7f5...
# INFO:__main__:Parsing task b1948b0a...
# INFO:__main__:Parsing task b230c067...
# INFO:__main__:Parsing task b27ca6d3...
# INFO:__main__:Parsing task b2862040...
# INFO:__main__:Parsing task b527c5c6...
# INFO:__main__:Parsing task b548a754...
# INFO:__main__:Parsing task b60334d2...
# INFO:__main__:Parsing task b6afb2da...
# INFO:__main__:Parsing task b7249182...
# INFO:__main__:Parsing task b775ac94...
# INFO:__main__:Parsing task b782dc8a...
# INFO:__main__:Parsing task b8825c91...
# INFO:__main__:Parsing task b8cdaf2b...
# INFO:__main__:Parsing task b91ae062...
# INFO:__main__:Parsing task b94a9452...
# INFO:__main__:Parsing task b9b7f026...
# INFO:__main__:Parsing task ba26e723...
# INFO:__main__:Parsing task ba97ae07...
# INFO:__main__:Parsing task bb43febb...
# INFO:__main__:Parsing task bbc9ae5d...
# INFO:__main__:Parsing task bc1d5164...
# INFO:__main__:Parsing task bd4472b8...
# INFO:__main__:Parsing task bda2d7a6...
# INFO:__main__:Parsing task bdad9b1f...
# INFO:__main__:Parsing task be94b721...
# INFO:__main__:Parsing task beb8660c...
# INFO:__main__:Parsing task c0f76784...
# INFO:__main__:Parsing task c1d99e64...
# INFO:__main__:Parsing task c3e719e8...
# INFO:__main__:Parsing task c3f564a4...
# INFO:__main__:Parsing task c444b776...
# INFO:__main__:Parsing task c59eb873...
# INFO:__main__:Parsing task c8cbb738...
# INFO:__main__:Parsing task c8f0f002...
# INFO:__main__:Parsing task c909285e...
# INFO:__main__:Parsing task c9e6f938...
# INFO:__main__:Parsing task c9f8e694...
# INFO:__main__:Parsing task caa06a1f...
# INFO:__main__:Parsing task cbded52d...
# INFO:__main__:Parsing task cce03e0d...
# INFO:__main__:Parsing task cdecee7f...
# INFO:__main__:Parsing task ce22a75a...
# INFO:__main__:Parsing task ce4f8723...
# INFO:__main__:Parsing task ce602527...
# INFO:__main__:Parsing task ce9e57f2...
# INFO:__main__:Parsing task cf98881b...
# INFO:__main__:Parsing task d037b0a7...
# INFO:__main__:Parsing task d06dbe63...
# INFO:__main__:Parsing task d07ae81c...
# INFO:__main__:Parsing task d0f5fe59...
# INFO:__main__:Parsing task d10ecb37...
# INFO:__main__:Parsing task d13f3404...
# INFO:__main__:Parsing task d22278a0...
# INFO:__main__:Parsing task d23f8c26...
# INFO:__main__:Parsing task d2abd087...
# INFO:__main__:Parsing task d364b489...
# INFO:__main__:Parsing task d406998b...
# INFO:__main__:Parsing task d43fd935...
# INFO:__main__:Parsing task d4469b4b...
# INFO:__main__:Parsing task d4a91cb9...
# INFO:__main__:Parsing task d4f3cd78...
# INFO:__main__:Parsing task d511f180...
# INFO:__main__:Parsing task d5d6de2d...
# INFO:__main__:Parsing task d631b094...
# INFO:__main__:Parsing task d687bc17...
# INFO:__main__:Parsing task d6ad076f...
# INFO:__main__:Parsing task d89b689b...
# INFO:__main__:Parsing task d8c310e9...
# INFO:__main__:Parsing task d90796e8...
# INFO:__main__:Parsing task d9f24cd1...
# INFO:__main__:Parsing task d9fac9be...
# INFO:__main__:Parsing task dae9d2b5...
# INFO:__main__:Parsing task db3e9e38...
# INFO:__main__:Parsing task db93a21d...
# INFO:__main__:Parsing task dbc1a6ce...
# INFO:__main__:Parsing task dc0a314f...
# INFO:__main__:Parsing task dc1df850...
# INFO:__main__:Parsing task dc433765...
# INFO:__main__:Parsing task ddf7fa4f...
# INFO:__main__:Parsing task de1cd16c...
# INFO:__main__:Parsing task ded97339...
# INFO:__main__:Parsing task e179c5f4...
# INFO:__main__:Parsing task e21d9049...
# INFO:__main__:Parsing task e26a3af2...
# INFO:__main__:Parsing task e3497940...
# INFO:__main__:Parsing task e40b9e2f...
# INFO:__main__:Parsing task e48d4e1a...
# INFO:__main__:Parsing task e5062a87...
# INFO:__main__:Parsing task e509e548...
# INFO:__main__:Parsing task e50d258f...
# INFO:__main__:Parsing task e6721834...
# INFO:__main__:Parsing task e73095fd...
# INFO:__main__:Parsing task e76a88a6...
# INFO:__main__:Parsing task e8593010...
# INFO:__main__:Parsing task e8dc4411...
# INFO:__main__:Parsing task e9614598...
# INFO:__main__:Parsing task e98196ab...
# INFO:__main__:Parsing task e9afcf9a...
# INFO:__main__:Parsing task ea32f347...
# INFO:__main__:Parsing task ea786f4a...
# INFO:__main__:Parsing task eb281b96...
# INFO:__main__:Parsing task eb5a1d5d...
# INFO:__main__:Parsing task ec883f72...
# INFO:__main__:Parsing task ecdecbb3...
# INFO:__main__:Parsing task ed36ccf7...
# INFO:__main__:Parsing task ef135b50...
# INFO:__main__:Parsing task f15e1fac...
# INFO:__main__:Parsing task f1cefba8...
# INFO:__main__:Parsing task f25fbde4...
# INFO:__main__:Parsing task f25ffba3...
# INFO:__main__:Parsing task f2829549...
# INFO:__main__:Parsing task f35d900a...
# INFO:__main__:Parsing task f5b8619d...
# INFO:__main__:Parsing task f76d97a5...
# INFO:__main__:Parsing task f8a8fe49...
# INFO:__main__:Parsing task f8b3ba0a...
# INFO:__main__:Parsing task f8c80d96...
# INFO:__main__:Parsing task f8ff0b80...
# INFO:__main__:Parsing task f9012d9b...
# INFO:__main__:Parsing task fafffa47...
# INFO:__main__:Parsing task fcb5c309...
# INFO:__main__:Parsing task fcc82909...
# INFO:__main__:Parsing task feca6190...
# INFO:__main__:Parsing task ff28f65a...
# INFO:__main__:Parsing task ff805c23...
# INFO:__main__:Total valid grid pairs extracted: 1302
# INFO:__main__:Parsing task 00576224...
# INFO:__main__:Parsing task 009d5c81...
# INFO:__main__:Parsing task 00dbd492...
# INFO:__main__:Parsing task 03560426...
# INFO:__main__:Parsing task 05a7bcf2...
# INFO:__main__:Parsing task 0607ce86...
# INFO:__main__:Parsing task 0692e18c...
# INFO:__main__:Parsing task 070dd51e...
# INFO:__main__:Parsing task 08573cc6...
# INFO:__main__:Parsing task 0934a4d8...
# INFO:__main__:Parsing task 09c534e7...
# INFO:__main__:Parsing task 0a1d4ef5...
# INFO:__main__:Parsing task 0a2355a6...
# INFO:__main__:Parsing task 0b17323b...
# INFO:__main__:Parsing task 0bb8deee...
# INFO:__main__:Parsing task 0becf7df...
# INFO:__main__:Parsing task 0c786b71...
# INFO:__main__:Parsing task 0c9aba6e...
# INFO:__main__:Parsing task 0d87d2a6...
# INFO:__main__:Parsing task 0e671a1a...
# INFO:__main__:Parsing task 0f63c0b9...
# INFO:__main__:Parsing task 103eff5b...
# INFO:__main__:Parsing task 11e1fe23...
# INFO:__main__:Parsing task 12422b43...
# INFO:__main__:Parsing task 12997ef3...
# INFO:__main__:Parsing task 12eac192...
# INFO:__main__:Parsing task 136b0064...
# INFO:__main__:Parsing task 13713586...
# INFO:__main__:Parsing task 137f0df0...
# INFO:__main__:Parsing task 140c817e...
# INFO:__main__:Parsing task 14754a24...
# INFO:__main__:Parsing task 15113be4...
# INFO:__main__:Parsing task 15663ba9...
# INFO:__main__:Parsing task 15696249...
# INFO:__main__:Parsing task 16b78196...
# INFO:__main__:Parsing task 17b80ad2...
# INFO:__main__:Parsing task 17cae0c1...
# INFO:__main__:Parsing task 18419cfa...
# INFO:__main__:Parsing task 184a9768...
# INFO:__main__:Parsing task 195ba7dc...
# INFO:__main__:Parsing task 1990f7a8...
# INFO:__main__:Parsing task 19bb5feb...
# INFO:__main__:Parsing task 1a2e2828...
# INFO:__main__:Parsing task 1a6449f1...
# INFO:__main__:Parsing task 1acc24af...
# INFO:__main__:Parsing task 1c02dbbe...
# INFO:__main__:Parsing task 1c0d0a4b...
# INFO:__main__:Parsing task 1c56ad9f...
# INFO:__main__:Parsing task 1d0a4b61...
# INFO:__main__:Parsing task 1d398264...
# INFO:__main__:Parsing task 1da012fc...
# INFO:__main__:Parsing task 1e81d6f9...
# INFO:__main__:Parsing task 1e97544e...
# INFO:__main__:Parsing task 2037f2c7...
# INFO:__main__:Parsing task 2072aba6...
# INFO:__main__:Parsing task 20818e16...
# INFO:__main__:Parsing task 20981f0e...
# INFO:__main__:Parsing task 212895b5...
# INFO:__main__:Parsing task 21f83797...
# INFO:__main__:Parsing task 22a4bbc2...
# INFO:__main__:Parsing task 25094a63...
# INFO:__main__:Parsing task 2546ccf6...
# INFO:__main__:Parsing task 256b0a75...
# INFO:__main__:Parsing task 2685904e...
# INFO:__main__:Parsing task 2697da3f...
# INFO:__main__:Parsing task 2753e76c...
# INFO:__main__:Parsing task 27a77e38...
# INFO:__main__:Parsing task 27f8ce4f...
# INFO:__main__:Parsing task 281123b4...
# INFO:__main__:Parsing task 292dd178...
# INFO:__main__:Parsing task 29700607...
# INFO:__main__:Parsing task 2a5f8217...
# INFO:__main__:Parsing task 2b01abd0...
# INFO:__main__:Parsing task 2c0b0aff...
# INFO:__main__:Parsing task 2c737e39...
# INFO:__main__:Parsing task 2f0c5170...
# INFO:__main__:Parsing task 310f3251...
# INFO:__main__:Parsing task 3194b014...
# INFO:__main__:Parsing task 319f2597...
# INFO:__main__:Parsing task 31adaf00...
# INFO:__main__:Parsing task 31d5ba1a...
# INFO:__main__:Parsing task 32e9702f...
# INFO:__main__:Parsing task 332efdb3...
# INFO:__main__:Parsing task 3391f8c0...
# INFO:__main__:Parsing task 33b52de3...
# INFO:__main__:Parsing task 3490cc26...
# INFO:__main__:Parsing task 34b99a2b...
# INFO:__main__:Parsing task 351d6448...
# INFO:__main__:Parsing task 358ba94e...
# INFO:__main__:Parsing task 37d3e8b2...
# INFO:__main__:Parsing task 3979b1a8...
# INFO:__main__:Parsing task 3a301edc...
# INFO:__main__:Parsing task 3b4c2228...
# INFO:__main__:Parsing task 3d31c5b3...
# INFO:__main__:Parsing task 3ed85e70...
# INFO:__main__:Parsing task 3ee1011a...
# INFO:__main__:Parsing task 3f23242b...
# INFO:__main__:Parsing task 40f6cd08...
# INFO:__main__:Parsing task 414297c0...
# INFO:__main__:Parsing task 423a55dc...
# INFO:__main__:Parsing task 42918530...
# INFO:__main__:Parsing task 42a15761...
# INFO:__main__:Parsing task 4364c1c4...
# INFO:__main__:Parsing task 456873bc...
# INFO:__main__:Parsing task 45737921...
# INFO:__main__:Parsing task 45bbe264...
# INFO:__main__:Parsing task 477d2879...
# INFO:__main__:Parsing task 47996f11...
# INFO:__main__:Parsing task 48131b3c...
# INFO:__main__:Parsing task 4852f2fa...
# INFO:__main__:Parsing task 48f8583b...
# INFO:__main__:Parsing task 4aab4007...
# INFO:__main__:Parsing task 4acc7107...
# INFO:__main__:Parsing task 4b6b68e5...
# INFO:__main__:Parsing task 4c177718...
# INFO:__main__:Parsing task 4cd1b7b2...
# INFO:__main__:Parsing task 4e45f183...
# INFO:__main__:Parsing task 4e469f39...
# INFO:__main__:Parsing task 4f537728...
# INFO:__main__:Parsing task 4ff4c9da...
# INFO:__main__:Parsing task 505fff84...
# INFO:__main__:Parsing task 506d28a5...
# INFO:__main__:Parsing task 50a16a69...
# INFO:__main__:Parsing task 50aad11f...
# INFO:__main__:Parsing task 50f325b5...
# INFO:__main__:Parsing task 516b51b7...
# INFO:__main__:Parsing task 5207a7b5...
# INFO:__main__:Parsing task 5289ad53...
# INFO:__main__:Parsing task 52fd389e...
# INFO:__main__:Parsing task 54db823b...
# INFO:__main__:Parsing task 55059096...
# INFO:__main__:Parsing task 551d5bf1...
# INFO:__main__:Parsing task 55783887...
# INFO:__main__:Parsing task 575b1a71...
# INFO:__main__:Parsing task 5783df64...
# INFO:__main__:Parsing task 5833af48...
# INFO:__main__:Parsing task 58743b76...
# INFO:__main__:Parsing task 58e15b12...
# INFO:__main__:Parsing task 59341089...
# INFO:__main__:Parsing task 5a5a2103...
# INFO:__main__:Parsing task 5af49b42...
# INFO:__main__:Parsing task 5b526a93...
# INFO:__main__:Parsing task 5b692c0f...
# INFO:__main__:Parsing task 5b6cbef5...
# INFO:__main__:Parsing task 5d2a5c43...
# INFO:__main__:Parsing task 5ffb2104...
# INFO:__main__:Parsing task 604001fa...
# INFO:__main__:Parsing task 60a26a3e...
# INFO:__main__:Parsing task 60c09cac...
# INFO:__main__:Parsing task 626c0bcc...
# INFO:__main__:Parsing task 62ab2642...
# INFO:__main__:Parsing task 62b74c02...
# INFO:__main__:Parsing task 639f5a19...
# INFO:__main__:Parsing task 642248e4...
# INFO:__main__:Parsing task 642d658d...
# INFO:__main__:Parsing task 64a7c07e...
# INFO:__main__:Parsing task 66e6c45b...
# INFO:__main__:Parsing task 66f2d22f...
# INFO:__main__:Parsing task 67636eac...
# INFO:__main__:Parsing task 67b4a34d...
# INFO:__main__:Parsing task 67c52801...
# INFO:__main__:Parsing task 68b67ca3...
# INFO:__main__:Parsing task 692cd3b6...
# INFO:__main__:Parsing task 695367ec...
# INFO:__main__:Parsing task 696d4842...
# INFO:__main__:Parsing task 69889d6e...
# INFO:__main__:Parsing task 6a11f6da...
# INFO:__main__:Parsing task 6ad5bdfd...
# INFO:__main__:Parsing task 6df30ad6...
# INFO:__main__:Parsing task 6ea4a07e...
# INFO:__main__:Parsing task 6f473927...
# INFO:__main__:Parsing task 7039b2d7...
# INFO:__main__:Parsing task 705a3229...
# INFO:__main__:Parsing task 712bf12e...
# INFO:__main__:Parsing task 72207abc...
# INFO:__main__:Parsing task 72a961c9...
# INFO:__main__:Parsing task 73182012...
# INFO:__main__:Parsing task 73c3b0d8...
# INFO:__main__:Parsing task 73ccf9c2...
# INFO:__main__:Parsing task 759f3fd3...
# INFO:__main__:Parsing task 762cd429...
# INFO:__main__:Parsing task 770cc55f...
# INFO:__main__:Parsing task 782b5218...
# INFO:__main__:Parsing task 79369cc6...
# INFO:__main__:Parsing task 7953d61e...
# INFO:__main__:Parsing task 79fb03f4...
# INFO:__main__:Parsing task 7bb29440...
# INFO:__main__:Parsing task 7c8af763...
# INFO:__main__:Parsing task 7c9b52a0...
# INFO:__main__:Parsing task 7d18a6fb...
# INFO:__main__:Parsing task 7d1f7ee8...
# INFO:__main__:Parsing task 7d419a02...
# INFO:__main__:Parsing task 7e02026e...
# INFO:__main__:Parsing task 7ee1c6ea...
# INFO:__main__:Parsing task 817e6c09...
# INFO:__main__:Parsing task 81c0276b...
# INFO:__main__:Parsing task 833dafe3...
# INFO:__main__:Parsing task 845d6e51...
# INFO:__main__:Parsing task 84db8fc4...
# INFO:__main__:Parsing task 84f2aca1...
# INFO:__main__:Parsing task 8597cfd7...
# INFO:__main__:Parsing task 85b81ff1...
# INFO:__main__:Parsing task 85fa5666...
# INFO:__main__:Parsing task 8719f442...
# INFO:__main__:Parsing task 88207623...
# INFO:__main__:Parsing task 891232d6...
# INFO:__main__:Parsing task 896d5239...
# INFO:__main__:Parsing task 8a371977...
# INFO:__main__:Parsing task 8b28cd80...
# INFO:__main__:Parsing task 8ba14f53...
# INFO:__main__:Parsing task 8cb8642d...
# INFO:__main__:Parsing task 8dae5dfc...
# INFO:__main__:Parsing task 8e2edd66...
# INFO:__main__:Parsing task 8ee62060...
# INFO:__main__:Parsing task 8fbca751...
# INFO:__main__:Parsing task 90347967...
# INFO:__main__:Parsing task 903d1b4a...
# INFO:__main__:Parsing task 9110e3c5...
# INFO:__main__:Parsing task 917bccba...
# INFO:__main__:Parsing task 929ab4e9...
# INFO:__main__:Parsing task 92e50de0...
# INFO:__main__:Parsing task 9356391f...
# INFO:__main__:Parsing task 93b4f4b3...
# INFO:__main__:Parsing task 93c31fbe...
# INFO:__main__:Parsing task 94133066...
# INFO:__main__:Parsing task 94414823...
# INFO:__main__:Parsing task 94be5b80...
# INFO:__main__:Parsing task 95a58926...
# INFO:__main__:Parsing task 963f59bc...
# INFO:__main__:Parsing task 96a8c0cd...
# INFO:__main__:Parsing task 97239e3d...
# INFO:__main__:Parsing task 9772c176...
# INFO:__main__:Parsing task 981571dc...
# INFO:__main__:Parsing task 992798f6...
# INFO:__main__:Parsing task 99306f82...
# INFO:__main__:Parsing task 9a4bb226...
# INFO:__main__:Parsing task 9b2a60aa...
# INFO:__main__:Parsing task 9b365c51...
# INFO:__main__:Parsing task 9b4c17c4...
# INFO:__main__:Parsing task 9bebae7a...
# INFO:__main__:Parsing task 9c1e755f...
# INFO:__main__:Parsing task 9c56f360...
# INFO:__main__:Parsing task 9caba7c3...
# INFO:__main__:Parsing task 9ddd00f0...
# INFO:__main__:Parsing task 9def23fe...
# INFO:__main__:Parsing task 9f27f097...
# INFO:__main__:Parsing task a04b2602...
# INFO:__main__:Parsing task a096bf4d...
# INFO:__main__:Parsing task a3f84088...
# INFO:__main__:Parsing task a406ac07...
# INFO:__main__:Parsing task a57f2f04...
# INFO:__main__:Parsing task a59b95c0...
# INFO:__main__:Parsing task a680ac02...
# INFO:__main__:Parsing task a8610ef7...
# INFO:__main__:Parsing task a934301b...
# INFO:__main__:Parsing task aa18de87...
# INFO:__main__:Parsing task aa300dc3...
# INFO:__main__:Parsing task aa4ec2a5...
# INFO:__main__:Parsing task aab50785...
# INFO:__main__:Parsing task ac0c5833...
# INFO:__main__:Parsing task ac2e8ecf...
# INFO:__main__:Parsing task ac3e2b04...
# INFO:__main__:Parsing task ac605cbb...
# INFO:__main__:Parsing task ad7e01d0...
# INFO:__main__:Parsing task ae58858e...
# INFO:__main__:Parsing task aee291af...
# INFO:__main__:Parsing task af22c60d...
# INFO:__main__:Parsing task af24b4cc...
# INFO:__main__:Parsing task b0722778...
# INFO:__main__:Parsing task b0f4d537...
# INFO:__main__:Parsing task b15fca0b...
# INFO:__main__:Parsing task b1fc8b8e...
# INFO:__main__:Parsing task b20f7c8b...
# INFO:__main__:Parsing task b457fec5...
# INFO:__main__:Parsing task b4a43f3b...
# INFO:__main__:Parsing task b7999b51...
# INFO:__main__:Parsing task b7cb93ac...
# INFO:__main__:Parsing task b7f8a4d8...
# INFO:__main__:Parsing task b7fb29bc...
# INFO:__main__:Parsing task b942fd60...
# INFO:__main__:Parsing task b9630600...
# INFO:__main__:Parsing task ba9d41b8...
# INFO:__main__:Parsing task baf41dbf...
# INFO:__main__:Parsing task bb52a14b...
# INFO:__main__:Parsing task bbb1b8b6...
# INFO:__main__:Parsing task bc4146bd...
# INFO:__main__:Parsing task bcb3040b...
# INFO:__main__:Parsing task bd14c3bf...
# INFO:__main__:Parsing task be03b35f...
# INFO:__main__:Parsing task bf32578f...
# INFO:__main__:Parsing task bf699163...
# INFO:__main__:Parsing task bf89d739...
# INFO:__main__:Parsing task c074846d...
# INFO:__main__:Parsing task c1990cce...
# INFO:__main__:Parsing task c3202e5a...
# INFO:__main__:Parsing task c35c1b4c...
# INFO:__main__:Parsing task c48954c1...
# INFO:__main__:Parsing task c62e2108...
# INFO:__main__:Parsing task c64f1187...
# INFO:__main__:Parsing task c658a4bd...
# INFO:__main__:Parsing task c663677b...
# INFO:__main__:Parsing task c6e1b8da...
# INFO:__main__:Parsing task c7d4e6ad...
# INFO:__main__:Parsing task c87289bb...
# INFO:__main__:Parsing task c8b7cc0f...
# INFO:__main__:Parsing task c92b942c...
# INFO:__main__:Parsing task c97c0139...
# INFO:__main__:Parsing task ca8de6ea...
# INFO:__main__:Parsing task ca8f78db...
# INFO:__main__:Parsing task cad67732...
# INFO:__main__:Parsing task cb227835...
# INFO:__main__:Parsing task ccd554ac...
# INFO:__main__:Parsing task cd3c21df...
# INFO:__main__:Parsing task ce039d91...
# INFO:__main__:Parsing task ce8d95cc...
# INFO:__main__:Parsing task cf133acc...
# INFO:__main__:Parsing task cfb2ce5a...
# INFO:__main__:Parsing task d017b73f...
# INFO:__main__:Parsing task d19f7514...
# INFO:__main__:Parsing task d282b262...
# INFO:__main__:Parsing task d2acf2cb...
# INFO:__main__:Parsing task d304284e...
# INFO:__main__:Parsing task d37a1ef5...
# INFO:__main__:Parsing task d47aa2ff...
# INFO:__main__:Parsing task d492a647...
# INFO:__main__:Parsing task d4b1c2b1...
# INFO:__main__:Parsing task d4c90558...
# INFO:__main__:Parsing task d56f2372...
# INFO:__main__:Parsing task d5c634a2...
# INFO:__main__:Parsing task d931c21c...
# INFO:__main__:Parsing task d94c3b52...
# INFO:__main__:Parsing task da2b0fe3...
# INFO:__main__:Parsing task da515329...
# INFO:__main__:Parsing task dc2aa30b...
# INFO:__main__:Parsing task dc2e9a9d...
# INFO:__main__:Parsing task dd2401ed...
# INFO:__main__:Parsing task de493100...
# INFO:__main__:Parsing task df8cc377...
# INFO:__main__:Parsing task e0fb7511...
# INFO:__main__:Parsing task e133d23d...
# INFO:__main__:Parsing task e1baa8a4...
# INFO:__main__:Parsing task e1d2900e...
# INFO:__main__:Parsing task e2092e0c...
# INFO:__main__:Parsing task e21a174a...
# INFO:__main__:Parsing task e345f17b...
# INFO:__main__:Parsing task e4075551...
# INFO:__main__:Parsing task e41c6fd3...
# INFO:__main__:Parsing task e57337a4...
# INFO:__main__:Parsing task e5790162...
# INFO:__main__:Parsing task e5c44e8f...
# INFO:__main__:Parsing task e619ca6e...
# INFO:__main__:Parsing task e633a9e5...
# INFO:__main__:Parsing task e66aafb8...
# INFO:__main__:Parsing task e681b708...
# INFO:__main__:Parsing task e69241bd...
# INFO:__main__:Parsing task e6de6e8f...
# INFO:__main__:Parsing task e74e1818...
# INFO:__main__:Parsing task e760a62e...
# INFO:__main__:Parsing task e7639916...
# INFO:__main__:Parsing task e78887d1...
# INFO:__main__:Parsing task e7a25a18...
# INFO:__main__:Parsing task e7b06bea...
# INFO:__main__:Parsing task e7dd8335...
# INFO:__main__:Parsing task e872b94a...
# INFO:__main__:Parsing task e88171ec...
# INFO:__main__:Parsing task e95e3d8e...
# INFO:__main__:Parsing task e99362f0...
# INFO:__main__:Parsing task e9ac8c9e...
# INFO:__main__:Parsing task e9b4f6fc...
# INFO:__main__:Parsing task e9bb6954...
# INFO:__main__:Parsing task e9c9d9a1...
# INFO:__main__:Parsing task ea959feb...
# INFO:__main__:Parsing task ea9794b1...
# INFO:__main__:Parsing task ecaa0ec1...
# INFO:__main__:Parsing task ed74f2f2...
# INFO:__main__:Parsing task ed98d772...
# INFO:__main__:Parsing task ef26cbf6...
# INFO:__main__:Parsing task f0afb749...
# INFO:__main__:Parsing task f0df5ff0...
# INFO:__main__:Parsing task f21745ec...
# INFO:__main__:Parsing task f3b10344...
# INFO:__main__:Parsing task f3cdc58f...
# INFO:__main__:Parsing task f3e62deb...
# INFO:__main__:Parsing task f4081712...
# INFO:__main__:Parsing task f45f5ca7...
# INFO:__main__:Parsing task f5aa3634...
# INFO:__main__:Parsing task f5c89df1...
# INFO:__main__:Parsing task f823c43c...
# INFO:__main__:Parsing task f83cb3f6...
# INFO:__main__:Parsing task f8be4b64...
# INFO:__main__:Parsing task f9a67cb5...
# INFO:__main__:Parsing task f9d67f8b...
# INFO:__main__:Parsing task fafd9572...
# INFO:__main__:Parsing task fb791726...
# INFO:__main__:Parsing task fc754716...
# INFO:__main__:Parsing task fd096ab6...
# INFO:__main__:Parsing task fd4b2b02...
# INFO:__main__:Parsing task fe9372f3...
# INFO:__main__:Parsing task fea12743...
# INFO:__main__:Parsing task ff72ca3e...
# INFO:__main__:Total valid grid pairs extracted: 1363
# Loading Data:  50%|██████████████████████████████████                                  | 50/100 [00:01<00:01, 29.18%/s]
# INFO:__main__:Node 'ARC Dataset' initialized.
# INFO:__main__:Node 'Task 007bbfb7' initialized.
# INFO:__main__:Node 'Output 007bbfb7' initialized.
# INFO:__main__:Embedding set for node 'Task 007bbfb7'.
# INFO:__main__:Embedding set for node 'Output 007bbfb7'.
# INFO:__main__:Created task node for 007bbfb7 with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 007bbfb7' initialized.
# INFO:__main__:Node 'Output 007bbfb7' initialized.
# INFO:__main__:Embedding set for node 'Task 007bbfb7'.
# INFO:__main__:Embedding set for node 'Output 007bbfb7'.
# INFO:__main__:Created task node for 007bbfb7 with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 007bbfb7' initialized.
# INFO:__main__:Node 'Output 007bbfb7' initialized.
# INFO:__main__:Embedding set for node 'Task 007bbfb7'.
# INFO:__main__:Embedding set for node 'Output 007bbfb7'.
# INFO:__main__:Created task node for 007bbfb7 with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 007bbfb7' initialized.
# INFO:__main__:Node 'Output 007bbfb7' initialized.
# INFO:__main__:Embedding set for node 'Task 007bbfb7'.
# INFO:__main__:Embedding set for node 'Output 007bbfb7'.
# INFO:__main__:Created task node for 007bbfb7 with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 007bbfb7' initialized.
# INFO:__main__:Node 'Output 007bbfb7' initialized.
# INFO:__main__:Embedding set for node 'Task 007bbfb7'.
# INFO:__main__:Embedding set for node 'Output 007bbfb7'.
# INFO:__main__:Created task node for 007bbfb7 with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 00d62c1b' initialized.
# INFO:__main__:Node 'Output 00d62c1b' initialized.
# INFO:__main__:Embedding set for node 'Task 00d62c1b'.
# INFO:__main__:Embedding set for node 'Output 00d62c1b'.
# INFO:__main__:Created task node for 00d62c1b with embedding shape: (6, 6)
# INFO:__main__:Node 'Task 00d62c1b' initialized.
# INFO:__main__:Node 'Output 00d62c1b' initialized.
# INFO:__main__:Embedding set for node 'Task 00d62c1b'.
# INFO:__main__:Embedding set for node 'Output 00d62c1b'.
# INFO:__main__:Created task node for 00d62c1b with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 00d62c1b' initialized.
# INFO:__main__:Node 'Output 00d62c1b' initialized.
# INFO:__main__:Embedding set for node 'Task 00d62c1b'.
# INFO:__main__:Embedding set for node 'Output 00d62c1b'.
# INFO:__main__:Created task node for 00d62c1b with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 00d62c1b' initialized.
# INFO:__main__:Node 'Output 00d62c1b' initialized.
# INFO:__main__:Embedding set for node 'Task 00d62c1b'.
# INFO:__main__:Embedding set for node 'Output 00d62c1b'.
# INFO:__main__:Created task node for 00d62c1b with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 00d62c1b' initialized.
# INFO:__main__:Node 'Output 00d62c1b' initialized.
# INFO:__main__:Embedding set for node 'Task 00d62c1b'.
# INFO:__main__:Embedding set for node 'Output 00d62c1b'.
# INFO:__main__:Created task node for 00d62c1b with embedding shape: (20, 20)
# INFO:__main__:Node 'Task 017c7c7b' initialized.
# INFO:__main__:Node 'Output 017c7c7b' initialized.
# INFO:__main__:Embedding set for node 'Task 017c7c7b'.
# INFO:__main__:Embedding set for node 'Output 017c7c7b'.
# INFO:__main__:Created task node for 017c7c7b with embedding shape: (6, 3)
# INFO:__main__:Node 'Task 017c7c7b' initialized.
# INFO:__main__:Node 'Output 017c7c7b' initialized.
# INFO:__main__:Embedding set for node 'Task 017c7c7b'.
# INFO:__main__:Embedding set for node 'Output 017c7c7b'.
# INFO:__main__:Created task node for 017c7c7b with embedding shape: (6, 3)
# INFO:__main__:Node 'Task 017c7c7b' initialized.
# INFO:__main__:Node 'Output 017c7c7b' initialized.
# INFO:__main__:Embedding set for node 'Task 017c7c7b'.
# INFO:__main__:Embedding set for node 'Output 017c7c7b'.
# INFO:__main__:Created task node for 017c7c7b with embedding shape: (6, 3)
# INFO:__main__:Node 'Task 025d127b' initialized.
# INFO:__main__:Node 'Output 025d127b' initialized.
# INFO:__main__:Embedding set for node 'Task 025d127b'.
# INFO:__main__:Embedding set for node 'Output 025d127b'.
# INFO:__main__:Created task node for 025d127b with embedding shape: (14, 9)
# INFO:__main__:Node 'Task 025d127b' initialized.
# INFO:__main__:Node 'Output 025d127b' initialized.
# INFO:__main__:Embedding set for node 'Task 025d127b'.
# INFO:__main__:Embedding set for node 'Output 025d127b'.
# INFO:__main__:Created task node for 025d127b with embedding shape: (8, 9)
# INFO:__main__:Node 'Task 045e512c' initialized.
# INFO:__main__:Node 'Output 045e512c' initialized.
# INFO:__main__:Embedding set for node 'Task 045e512c'.
# INFO:__main__:Embedding set for node 'Output 045e512c'.
# INFO:__main__:Created task node for 045e512c with embedding shape: (21, 21)
# INFO:__main__:Node 'Task 045e512c' initialized.
# INFO:__main__:Node 'Output 045e512c' initialized.
# INFO:__main__:Embedding set for node 'Task 045e512c'.
# INFO:__main__:Embedding set for node 'Output 045e512c'.
# INFO:__main__:Created task node for 045e512c with embedding shape: (21, 21)
# INFO:__main__:Node 'Task 045e512c' initialized.
# INFO:__main__:Node 'Output 045e512c' initialized.
# INFO:__main__:Embedding set for node 'Task 045e512c'.
# INFO:__main__:Embedding set for node 'Output 045e512c'.
# INFO:__main__:Created task node for 045e512c with embedding shape: (21, 21)
# INFO:__main__:Node 'Task 0520fde7' initialized.
# INFO:__main__:Node 'Output 0520fde7' initialized.
# INFO:__main__:Embedding set for node 'Task 0520fde7'.
# INFO:__main__:Embedding set for node 'Output 0520fde7'.
# INFO:__main__:Created task node for 0520fde7 with embedding shape: (3, 7)
# INFO:__main__:Node 'Task 0520fde7' initialized.
# INFO:__main__:Node 'Output 0520fde7' initialized.
# INFO:__main__:Embedding set for node 'Task 0520fde7'.
# INFO:__main__:Embedding set for node 'Output 0520fde7'.
# INFO:__main__:Created task node for 0520fde7 with embedding shape: (3, 7)
# INFO:__main__:Node 'Task 0520fde7' initialized.
# INFO:__main__:Node 'Output 0520fde7' initialized.
# INFO:__main__:Embedding set for node 'Task 0520fde7'.
# INFO:__main__:Embedding set for node 'Output 0520fde7'.
# INFO:__main__:Created task node for 0520fde7 with embedding shape: (3, 7)
# INFO:__main__:Node 'Task 05269061' initialized.
# INFO:__main__:Node 'Output 05269061' initialized.
# INFO:__main__:Embedding set for node 'Task 05269061'.
# INFO:__main__:Embedding set for node 'Output 05269061'.
# INFO:__main__:Created task node for 05269061 with embedding shape: (7, 7)
# INFO:__main__:Node 'Task 05269061' initialized.
# INFO:__main__:Node 'Output 05269061' initialized.
# INFO:__main__:Embedding set for node 'Task 05269061'.
# INFO:__main__:Embedding set for node 'Output 05269061'.
# INFO:__main__:Created task node for 05269061 with embedding shape: (7, 7)
# INFO:__main__:Node 'Task 05269061' initialized.
# INFO:__main__:Node 'Output 05269061' initialized.
# INFO:__main__:Embedding set for node 'Task 05269061'.
# INFO:__main__:Embedding set for node 'Output 05269061'.
# INFO:__main__:Created task node for 05269061 with embedding shape: (7, 7)
# INFO:__main__:Node 'Task 05f2a901' initialized.
# INFO:__main__:Node 'Output 05f2a901' initialized.
# INFO:__main__:Embedding set for node 'Task 05f2a901'.
# INFO:__main__:Embedding set for node 'Output 05f2a901'.
# INFO:__main__:Created task node for 05f2a901 with embedding shape: (14, 9)
# INFO:__main__:Node 'Task 05f2a901' initialized.
# INFO:__main__:Node 'Output 05f2a901' initialized.
# INFO:__main__:Embedding set for node 'Task 05f2a901'.
# INFO:__main__:Embedding set for node 'Output 05f2a901'.
# INFO:__main__:Created task node for 05f2a901 with embedding shape: (9, 10)
# INFO:__main__:Node 'Task 05f2a901' initialized.
# INFO:__main__:Node 'Output 05f2a901' initialized.
# INFO:__main__:Embedding set for node 'Task 05f2a901'.
# INFO:__main__:Embedding set for node 'Output 05f2a901'.
# INFO:__main__:Created task node for 05f2a901 with embedding shape: (11, 10)
# INFO:__main__:Node 'Task 06df4c85' initialized.
# INFO:__main__:Node 'Output 06df4c85' initialized.
# INFO:__main__:Embedding set for node 'Task 06df4c85'.
# INFO:__main__:Embedding set for node 'Output 06df4c85'.
# INFO:__main__:Created task node for 06df4c85 with embedding shape: (20, 20)
# INFO:__main__:Node 'Task 06df4c85' initialized.
# INFO:__main__:Node 'Output 06df4c85' initialized.
# INFO:__main__:Embedding set for node 'Task 06df4c85'.
# INFO:__main__:Embedding set for node 'Output 06df4c85'.
# INFO:__main__:Created task node for 06df4c85 with embedding shape: (23, 23)
# INFO:__main__:Node 'Task 06df4c85' initialized.
# INFO:__main__:Node 'Output 06df4c85' initialized.
# INFO:__main__:Embedding set for node 'Task 06df4c85'.
# INFO:__main__:Embedding set for node 'Output 06df4c85'.
# INFO:__main__:Created task node for 06df4c85 with embedding shape: (23, 23)
# INFO:__main__:Node 'Task 08ed6ac7' initialized.
# INFO:__main__:Node 'Output 08ed6ac7' initialized.
# INFO:__main__:Embedding set for node 'Task 08ed6ac7'.
# INFO:__main__:Embedding set for node 'Output 08ed6ac7'.
# INFO:__main__:Created task node for 08ed6ac7 with embedding shape: (9, 9)
# INFO:__main__:Node 'Task 08ed6ac7' initialized.
# INFO:__main__:Node 'Output 08ed6ac7' initialized.
# INFO:__main__:Embedding set for node 'Task 08ed6ac7'.
# INFO:__main__:Embedding set for node 'Output 08ed6ac7'.
# INFO:__main__:Created task node for 08ed6ac7 with embedding shape: (9, 9)
# INFO:__main__:Node 'Task 09629e4f' initialized.
# INFO:__main__:Node 'Output 09629e4f' initialized.
# INFO:__main__:Embedding set for node 'Task 09629e4f'.
# INFO:__main__:Embedding set for node 'Output 09629e4f'.
# INFO:__main__:Created task node for 09629e4f with embedding shape: (11, 11)
# INFO:__main__:Node 'Task 09629e4f' initialized.
# INFO:__main__:Node 'Output 09629e4f' initialized.
# INFO:__main__:Embedding set for node 'Task 09629e4f'.
# INFO:__main__:Embedding set for node 'Output 09629e4f'.
# INFO:__main__:Created task node for 09629e4f with embedding shape: (11, 11)
# INFO:__main__:Node 'Task 09629e4f' initialized.
# INFO:__main__:Node 'Output 09629e4f' initialized.
# INFO:__main__:Embedding set for node 'Task 09629e4f'.
# INFO:__main__:Embedding set for node 'Output 09629e4f'.
# INFO:__main__:Created task node for 09629e4f with embedding shape: (11, 11)
# INFO:__main__:Node 'Task 09629e4f' initialized.
# INFO:__main__:Node 'Output 09629e4f' initialized.
# INFO:__main__:Embedding set for node 'Task 09629e4f'.
# INFO:__main__:Embedding set for node 'Output 09629e4f'.
# INFO:__main__:Created task node for 09629e4f with embedding shape: (11, 11)
# INFO:__main__:Node 'Task 0962bcdd' initialized.
# INFO:__main__:Node 'Output 0962bcdd' initialized.
# INFO:__main__:Embedding set for node 'Task 0962bcdd'.
# INFO:__main__:Embedding set for node 'Output 0962bcdd'.
# INFO:__main__:Created task node for 0962bcdd with embedding shape: (12, 12)
# INFO:__main__:Node 'Task 0962bcdd' initialized.
# INFO:__main__:Node 'Output 0962bcdd' initialized.
# INFO:__main__:Embedding set for node 'Task 0962bcdd'.
# INFO:__main__:Embedding set for node 'Output 0962bcdd'.
# INFO:__main__:Created task node for 0962bcdd with embedding shape: (12, 12)
# INFO:__main__:Node 'Task 0a938d79' initialized.
# INFO:__main__:Node 'Output 0a938d79' initialized.
# INFO:__main__:Embedding set for node 'Task 0a938d79'.
# INFO:__main__:Embedding set for node 'Output 0a938d79'.
# INFO:__main__:Created task node for 0a938d79 with embedding shape: (10, 25)
# INFO:__main__:Node 'Task 0a938d79' initialized.
# INFO:__main__:Node 'Output 0a938d79' initialized.
# INFO:__main__:Embedding set for node 'Task 0a938d79'.
# INFO:__main__:Embedding set for node 'Output 0a938d79'.
# INFO:__main__:Created task node for 0a938d79 with embedding shape: (7, 23)
# INFO:__main__:Node 'Task 0a938d79' initialized.
# INFO:__main__:Node 'Output 0a938d79' initialized.
# INFO:__main__:Embedding set for node 'Task 0a938d79'.
# INFO:__main__:Embedding set for node 'Output 0a938d79'.
# INFO:__main__:Created task node for 0a938d79 with embedding shape: (22, 9)
# INFO:__main__:Node 'Task 0a938d79' initialized.
# INFO:__main__:Node 'Output 0a938d79' initialized.
# INFO:__main__:Embedding set for node 'Task 0a938d79'.
# INFO:__main__:Embedding set for node 'Output 0a938d79'.
# INFO:__main__:Created task node for 0a938d79 with embedding shape: (24, 8)
# INFO:__main__:Node 'Task 0b148d64' initialized.
# INFO:__main__:Node 'Output 0b148d64' initialized.
# INFO:__main__:Embedding set for node 'Task 0b148d64'.
# INFO:__main__:Embedding set for node 'Output 0b148d64'.
# INFO:__main__:Created task node for 0b148d64 with embedding shape: (21, 21)
# INFO:__main__:Node 'Task 0b148d64' initialized.
# INFO:__main__:Node 'Output 0b148d64' initialized.
# INFO:__main__:Embedding set for node 'Task 0b148d64'.
# INFO:__main__:Embedding set for node 'Output 0b148d64'.
# INFO:__main__:Created task node for 0b148d64 with embedding shape: (18, 19)
# INFO:__main__:Node 'Task 0b148d64' initialized.
# INFO:__main__:Node 'Output 0b148d64' initialized.
# INFO:__main__:Embedding set for node 'Task 0b148d64'.
# INFO:__main__:Embedding set for node 'Output 0b148d64'.
# INFO:__main__:Created task node for 0b148d64 with embedding shape: (19, 17)
# INFO:__main__:Node 'Task 0ca9ddb6' initialized.
# INFO:__main__:Node 'Output 0ca9ddb6' initialized.
# INFO:__main__:Embedding set for node 'Task 0ca9ddb6'.
# INFO:__main__:Embedding set for node 'Output 0ca9ddb6'.
# INFO:__main__:Created task node for 0ca9ddb6 with embedding shape: (9, 9)
# INFO:__main__:Node 'Task 0ca9ddb6' initialized.
# INFO:__main__:Node 'Output 0ca9ddb6' initialized.
# INFO:__main__:Embedding set for node 'Task 0ca9ddb6'.
# INFO:__main__:Embedding set for node 'Output 0ca9ddb6'.
# INFO:__main__:Created task node for 0ca9ddb6 with embedding shape: (9, 9)
# INFO:__main__:Node 'Task 0ca9ddb6' initialized.
# INFO:__main__:Node 'Output 0ca9ddb6' initialized.
# INFO:__main__:Embedding set for node 'Task 0ca9ddb6'.
# INFO:__main__:Embedding set for node 'Output 0ca9ddb6'.
# INFO:__main__:Created task node for 0ca9ddb6 with embedding shape: (9, 9)
# INFO:__main__:Node 'Task 0d3d703e' initialized.
# INFO:__main__:Node 'Output 0d3d703e' initialized.
# INFO:__main__:Embedding set for node 'Task 0d3d703e'.
# INFO:__main__:Embedding set for node 'Output 0d3d703e'.
# INFO:__main__:Created task node for 0d3d703e with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 0d3d703e' initialized.
# INFO:__main__:Node 'Output 0d3d703e' initialized.
# INFO:__main__:Embedding set for node 'Task 0d3d703e'.
# INFO:__main__:Embedding set for node 'Output 0d3d703e'.
# INFO:__main__:Created task node for 0d3d703e with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 0d3d703e' initialized.
# INFO:__main__:Node 'Output 0d3d703e' initialized.
# INFO:__main__:Embedding set for node 'Task 0d3d703e'.
# INFO:__main__:Embedding set for node 'Output 0d3d703e'.
# INFO:__main__:Created task node for 0d3d703e with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 0d3d703e' initialized.
# INFO:__main__:Node 'Output 0d3d703e' initialized.
# INFO:__main__:Embedding set for node 'Task 0d3d703e'.
# INFO:__main__:Embedding set for node 'Output 0d3d703e'.
# INFO:__main__:Created task node for 0d3d703e with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 0dfd9992' initialized.
# INFO:__main__:Node 'Output 0dfd9992' initialized.
# INFO:__main__:Embedding set for node 'Task 0dfd9992'.
# INFO:__main__:Embedding set for node 'Output 0dfd9992'.
# INFO:__main__:Created task node for 0dfd9992 with embedding shape: (21, 21)
# INFO:__main__:Node 'Task 0dfd9992' initialized.
# INFO:__main__:Node 'Output 0dfd9992' initialized.
# INFO:__main__:Embedding set for node 'Task 0dfd9992'.
# INFO:__main__:Embedding set for node 'Output 0dfd9992'.
# INFO:__main__:Created task node for 0dfd9992 with embedding shape: (21, 21)
# INFO:__main__:Node 'Task 0dfd9992' initialized.
# INFO:__main__:Node 'Output 0dfd9992' initialized.
# INFO:__main__:Embedding set for node 'Task 0dfd9992'.
# INFO:__main__:Embedding set for node 'Output 0dfd9992'.
# INFO:__main__:Created task node for 0dfd9992 with embedding shape: (21, 21)
# INFO:__main__:Node 'Task 0e206a2e' initialized.
# INFO:__main__:Node 'Output 0e206a2e' initialized.
# INFO:__main__:Embedding set for node 'Task 0e206a2e'.
# INFO:__main__:Embedding set for node 'Output 0e206a2e'.
# INFO:__main__:Created task node for 0e206a2e with embedding shape: (14, 18)
# INFO:__main__:Node 'Task 0e206a2e' initialized.
# INFO:__main__:Node 'Output 0e206a2e' initialized.
# ...
# INFO:__main__:Node 'Task 27a28665' initialized.
# INFO:__main__:Node 'Output 27a28665' initialized.
# INFO:__main__:Embedding set for node 'Task 27a28665'.
# INFO:__main__:Embedding set for node 'Output 27a28665'.
# INFO:__main__:Created task node for 27a28665 with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 27a28665' initialized.
# INFO:__main__:Node 'Output 27a28665' initialized.
# INFO:__main__:Embedding set for node 'Task 27a28665'.
# INFO:__main__:Embedding set for node 'Output 27a28665'.
# INFO:__main__:Created task node for 27a28665 with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 27a28665' initialized.
# INFO:__main__:Node 'Output 27a28665' initialized.
# INFO:__main__:Embedding set for node 'Task 27a28665'.
# INFO:__main__:Embedding set for node 'Output 27a28665'.
# INFO:__main__:Created task node for 27a28665 with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 27a28665' initialized.
# INFO:__main__:Node 'Output 27a28665' initialized.
# INFO:__main__:Embedding set for node 'Task 27a28665'.
# INFO:__main__:Embedding set for node 'Output 27a28665'.
# INFO:__main__:Created task node for 27a28665 with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 27a28665' initialized.
# INFO:__main__:Node 'Output 27a28665' initialized.
# INFO:__main__:Embedding set for node 'Task 27a28665'.
# INFO:__main__:Embedding set for node 'Output 27a28665'.
# INFO:__main__:Created task node for 27a28665 with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 27a28665' initialized.
# INFO:__main__:Node 'Output 27a28665' initialized.
# INFO:__main__:Embedding set for node 'Task 27a28665'.
# INFO:__main__:Embedding set for node 'Output 27a28665'.
# INFO:__main__:Created task node for 27a28665 with embedding shape: (3, 3)
# INFO:__main__:Node 'Task 28bf18c6' initialized.
# INFO:__main__:Node 'Output 28bf18c6' initialized.
# INFO:__main__:Embedding set for node 'Task 28bf18c6'.
# INFO:__main__:Embedding set for node 'Output 28bf18c6'.
# INFO:__main__:Created task node for 28bf18c6 with embedding shape: (8, 8)
# INFO:__main__:Node 'Task 28bf18c6' initialized.
# INFO:__main__:Node 'Output 28bf18c6' initialized.
# INFO:__main__:Embedding set for node 'Task 28bf18c6'.
# INFO:__main__:Embedding set for node 'Output 28bf18c6'.
# INFO:__main__:Created task node for 28bf18c6 with embedding shape: (8, 8)
# INFO:__main__:Node 'Task 28bf18c6' initialized.
# INFO:__main__:Node 'Output 28bf18c6' initialized.
# INFO:__main__:Embedding set for node 'Task 28bf18c6'.
# INFO:__main__:Embedding set for node 'Output 28bf18c6'.
# INFO:__main__:Created task node for 28bf18c6 with embedding shape: (8, 8)
# INFO:__main__:Node 'Task 28e73c20' initialized.
# INFO:__main__:Node 'Output 28e73c20' initialized.
# INFO:__main__:Embedding set for node 'Task 28e73c20'.
# INFO:__main__:Embedding set for node 'Output 28e73c20'.
# INFO:__main__:Created task node for 28e73c20 with embedding shape: (6, 6)
# INFO:__main__:Node 'Task 28e73c20' initialized.
# INFO:__main__:Node 'Output 28e73c20' initialized.
# INFO:__main__:Embedding set for node 'Task 28e73c20'.
# INFO:__main__:Embedding set for node 'Output 28e73c20'.
# INFO:__main__:Created task node for 28e73c20 with embedding shape: (8, 8)
# INFO:__main__:Node 'Task 28e73c20' initialized.
# INFO:__main__:Node 'Output 28e73c20' initialized.
# INFO:__main__:Embedding set for node 'Task 28e73c20'.
# INFO:__main__:Embedding set for node 'Output 28e73c20'.
# INFO:__main__:Created task node for 28e73c20 with embedding shape: (15, 15)
# INFO:__main__:Node 'Task 28e73c20' initialized.
# INFO:__main__:Node 'Output 28e73c20' initialized.
# INFO:__main__:Embedding set for node 'Task 28e73c20'.
# INFO:__main__:Embedding set for node 'Output 28e73c20'.
# INFO:__main__:Created task node for 28e73c20 with embedding shape: (13, 13)
# INFO:__main__:Node 'Task 28e73c20' initialized.
# INFO:__main__:Node 'Output 28e73c20' initialized.
# INFO:__main__:Embedding set for node 'Task 28e73c20'.
# INFO:__main__:Embedding set for node 'Output 28e73c20'.
# INFO:__main__:Created task node for 28e73c20 with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 29623171' initialized.
# INFO:__main__:Node 'Output 29623171' initialized.
# INFO:__main__:Embedding set for node 'Task 29623171'.
# INFO:__main__:Embedding set for node 'Output 29623171'.
# INFO:__main__:Created task node for 29623171 with embedding shape: (11, 11)
# INFO:__main__:Node 'Task 29623171' initialized.
# INFO:__main__:Node 'Output 29623171' initialized.
# INFO:__main__:Embedding set for node 'Task 29623171'.
# INFO:__main__:Embedding set for node 'Output 29623171'.
# INFO:__main__:Created task node for 29623171 with embedding shape: (11, 11)
# INFO:__main__:Node 'Task 29623171' initialized.
# INFO:__main__:Node 'Output 29623171' initialized.
# INFO:__main__:Embedding set for node 'Task 29623171'.
# INFO:__main__:Embedding set for node 'Output 29623171'.
# INFO:__main__:Created task node for 29623171 with embedding shape: (11, 11)
# INFO:__main__:Node 'Task 29c11459' initialized.
# INFO:__main__:Node 'Output 29c11459' initialized.
# INFO:__main__:Embedding set for node 'Task 29c11459'.
# INFO:__main__:Embedding set for node 'Output 29c11459'.
# INFO:__main__:Created task node for 29c11459 with embedding shape: (5, 11)
# INFO:__main__:Node 'Task 29c11459' initialized.
# INFO:__main__:Node 'Output 29c11459' initialized.
# INFO:__main__:Embedding set for node 'Task 29c11459'.
# INFO:__main__:Embedding set for node 'Output 29c11459'.
# INFO:__main__:Created task node for 29c11459 with embedding shape: (5, 11)
# INFO:__main__:Node 'Task 29ec7d0e' initialized.
# INFO:__main__:Node 'Output 29ec7d0e' initialized.
# INFO:__main__:Embedding set for node 'Task 29ec7d0e'.
# INFO:__main__:Embedding set for node 'Output 29ec7d0e'.
# INFO:__main__:Created task node for 29ec7d0e with embedding shape: (18, 18)
# INFO:__main__:Node 'Task 29ec7d0e' initialized.
# INFO:__main__:Node 'Output 29ec7d0e' initialized.
# INFO:__main__:Embedding set for node 'Task 29ec7d0e'.
# INFO:__main__:Embedding set for node 'Output 29ec7d0e'.
# INFO:__main__:Created task node for 29ec7d0e with embedding shape: (18, 18)
# INFO:__main__:Node 'Task 29ec7d0e' initialized.
# INFO:__main__:Node 'Output 29ec7d0e' initialized.
# INFO:__main__:Embedding set for node 'Task 29ec7d0e'.
# INFO:__main__:Embedding set for node 'Output 29ec7d0e'.
# INFO:__main__:Created task node for 29ec7d0e with embedding shape: (18, 18)
# INFO:__main__:Node 'Task 29ec7d0e' initialized.
# INFO:__main__:Node 'Output 29ec7d0e' initialized.
# INFO:__main__:Embedding set for node 'Task 29ec7d0e'.
# INFO:__main__:Embedding set for node 'Output 29ec7d0e'.
# INFO:__main__:Created task node for 29ec7d0e with embedding shape: (18, 18)
# INFO:__main__:Node 'Task 2bcee788' initialized.
# INFO:__main__:Node 'Output 2bcee788' initialized.
# INFO:__main__:Embedding set for node 'Task 2bcee788'.
# INFO:__main__:Embedding set for node 'Output 2bcee788'.
# INFO:__main__:Created task node for 2bcee788 with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 2bcee788' initialized.
# INFO:__main__:Node 'Output 2bcee788' initialized.
# INFO:__main__:Embedding set for node 'Task 2bcee788'.
# INFO:__main__:Embedding set for node 'Output 2bcee788'.
# INFO:__main__:Created task node for 2bcee788 with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 2bcee788' initialized.
# INFO:__main__:Node 'Output 2bcee788' initialized.
# INFO:__main__:Embedding set for node 'Task 2bcee788'.
# INFO:__main__:Embedding set for node 'Output 2bcee788'.
# INFO:__main__:Created task node for 2bcee788 with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 2bcee788' initialized.
# INFO:__main__:Node 'Output 2bcee788' initialized.
# INFO:__main__:Embedding set for node 'Task 2bcee788'.
# INFO:__main__:Embedding set for node 'Output 2bcee788'.
# INFO:__main__:Created task node for 2bcee788 with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 2bee17df' initialized.
# INFO:__main__:Node 'Output 2bee17df' initialized.
# INFO:__main__:Embedding set for node 'Task 2bee17df'.
# INFO:__main__:Embedding set for node 'Output 2bee17df'.
# INFO:__main__:Created task node for 2bee17df with embedding shape: (12, 12)
# INFO:__main__:Node 'Task 2bee17df' initialized.
# INFO:__main__:Node 'Output 2bee17df' initialized.
# INFO:__main__:Embedding set for node 'Task 2bee17df'.
# INFO:__main__:Embedding set for node 'Output 2bee17df'.
# INFO:__main__:Created task node for 2bee17df with embedding shape: (12, 12)
# INFO:__main__:Node 'Task 2bee17df' initialized.
# INFO:__main__:Node 'Output 2bee17df' initialized.
# INFO:__main__:Embedding set for node 'Task 2bee17df'.
# INFO:__main__:Embedding set for node 'Output 2bee17df'.
# INFO:__main__:Created task node for 2bee17df with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 2c608aff' initialized.
# INFO:__main__:Node 'Output 2c608aff' initialized.
# INFO:__main__:Embedding set for node 'Task 2c608aff'.
# INFO:__main__:Embedding set for node 'Output 2c608aff'.
# INFO:__main__:Created task node for 2c608aff with embedding shape: (9, 12)
# INFO:__main__:Node 'Task 2c608aff' initialized.
# INFO:__main__:Node 'Output 2c608aff' initialized.
# INFO:__main__:Embedding set for node 'Task 2c608aff'.
# INFO:__main__:Embedding set for node 'Output 2c608aff'.
# INFO:__main__:Created task node for 2c608aff with embedding shape: (10, 12)
# INFO:__main__:Node 'Task 2c608aff' initialized.
# INFO:__main__:Node 'Output 2c608aff' initialized.
# INFO:__main__:Embedding set for node 'Task 2c608aff'.
# INFO:__main__:Embedding set for node 'Output 2c608aff'.
# INFO:__main__:Created task node for 2c608aff with embedding shape: (14, 12)
# INFO:__main__:Node 'Task 2c608aff' initialized.
# INFO:__main__:Node 'Output 2c608aff' initialized.
# INFO:__main__:Embedding set for node 'Task 2c608aff'.
# INFO:__main__:Embedding set for node 'Output 2c608aff'.
# INFO:__main__:Created task node for 2c608aff with embedding shape: (14, 18)
# INFO:__main__:Node 'Task 2dc579da' initialized.
# INFO:__main__:Node 'Output 2dc579da' initialized.
# INFO:__main__:Embedding set for node 'Task 2dc579da'.
# INFO:__main__:Embedding set for node 'Output 2dc579da'.
# INFO:__main__:Created task node for 2dc579da with embedding shape: (5, 5)
# INFO:__main__:Node 'Task 2dc579da' initialized.
# INFO:__main__:Node 'Output 2dc579da' initialized.
# INFO:__main__:Embedding set for node 'Task 2dc579da'.
# INFO:__main__:Embedding set for node 'Output 2dc579da'.
# INFO:__main__:Created task node for 2dc579da with embedding shape: (7, 7)
# INFO:__main__:Node 'Task 2dc579da' initialized.
# INFO:__main__:Node 'Output 2dc579da' initialized.
# INFO:__main__:Embedding set for node 'Task 2dc579da'.
# INFO:__main__:Embedding set for node 'Output 2dc579da'.
# INFO:__main__:Created task node for 2dc579da with embedding shape: (11, 11)
# INFO:__main__:Node 'Task 2dd70a9a' initialized.
# INFO:__main__:Node 'Output 2dd70a9a' initialized.
# INFO:__main__:Embedding set for node 'Task 2dd70a9a'.
# INFO:__main__:Embedding set for node 'Output 2dd70a9a'.
# INFO:__main__:Created task node for 2dd70a9a with embedding shape: (20, 20)
# INFO:__main__:Node 'Task 2dd70a9a' initialized.
# INFO:__main__:Node 'Output 2dd70a9a' initialized.
# INFO:__main__:Embedding set for node 'Task 2dd70a9a'.
# INFO:__main__:Embedding set for node 'Output 2dd70a9a'.
# INFO:__main__:Created task node for 2dd70a9a with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 2dd70a9a' initialized.
# INFO:__main__:Node 'Output 2dd70a9a' initialized.
# INFO:__main__:Embedding set for node 'Task 2dd70a9a'.
# INFO:__main__:Embedding set for node 'Output 2dd70a9a'.
# INFO:__main__:Created task node for 2dd70a9a with embedding shape: (15, 15)
# INFO:__main__:Node 'Task 2dee498d' initialized.
# INFO:__main__:Node 'Output 2dee498d' initialized.
# INFO:__main__:Embedding set for node 'Task 2dee498d'.
# INFO:__main__:Embedding set for node 'Output 2dee498d'.
# INFO:__main__:Created task node for 2dee498d with embedding shape: (3, 9)
# INFO:__main__:Node 'Task 2dee498d' initialized.
# INFO:__main__:Node 'Output 2dee498d' initialized.
# INFO:__main__:Embedding set for node 'Task 2dee498d'.
# INFO:__main__:Embedding set for node 'Output 2dee498d'.
# INFO:__main__:Created task node for 2dee498d with embedding shape: (4, 12)
# INFO:__main__:Node 'Task 2dee498d' initialized.
# INFO:__main__:Node 'Output 2dee498d' initialized.
# INFO:__main__:Embedding set for node 'Task 2dee498d'.
# INFO:__main__:Embedding set for node 'Output 2dee498d'.
# INFO:__main__:Created task node for 2dee498d with embedding shape: (2, 6)
# INFO:__main__:Node 'Task 31aa019c' initialized.
# INFO:__main__:Node 'Output 31aa019c' initialized.
# INFO:__main__:Embedding set for node 'Task 31aa019c'.
# INFO:__main__:Embedding set for node 'Output 31aa019c'.
# INFO:__main__:Created task node for 31aa019c with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 31aa019c' initialized.
# INFO:__main__:Node 'Output 31aa019c' initialized.
# INFO:__main__:Embedding set for node 'Task 31aa019c'.
# INFO:__main__:Embedding set for node 'Output 31aa019c'.
# INFO:__main__:Created task node for 31aa019c with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 31aa019c' initialized.
# INFO:__main__:Node 'Output 31aa019c' initialized.
# INFO:__main__:Embedding set for node 'Task 31aa019c'.
# INFO:__main__:Embedding set for node 'Output 31aa019c'.
# INFO:__main__:Created task node for 31aa019c with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 321b1fc6' initialized.
# INFO:__main__:Node 'Output 321b1fc6' initialized.
# INFO:__main__:Embedding set for node 'Task 321b1fc6'.
# INFO:__main__:Embedding set for node 'Output 321b1fc6'.
# INFO:__main__:Created task node for 321b1fc6 with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 321b1fc6' initialized.
# INFO:__main__:Node 'Output 321b1fc6' initialized.
# INFO:__main__:Embedding set for node 'Task 321b1fc6'.
# INFO:__main__:Embedding set for node 'Output 321b1fc6'.
# INFO:__main__:Created task node for 321b1fc6 with embedding shape: (10, 10)
# INFO:__main__:Node 'Task 32597951' initialized.
# INFO:__main__:Node 'Output 32597951' initialized.
# INFO:__main__:Embedding set for node 'Task 32597951'.
# INFO:__main__:Embedding set for node 'Output 32597951'.
# INFO:__main__:Created task node for 32597951 with embedding shape: (17, 17)
# INFO:__main__:Node 'Task 32597951' initialized.
# INFO:__main__:Node 'Output 32597951' initialized.
# INFO:__main__:Embedding set for node 'Task 32597951'.
# INFO:__main__:Embedding set for node 'Output 32597951'.
# INFO:__main__:Created task node for 32597951 with embedding shape: (17, 17)
# INFO:__main__:Node 'Task 32597951' initialized.
# INFO:__main__:Node 'Output 32597951' initialized.
# INFO:__main__:Embedding set for node 'Task 32597951'.
# INFO:__main__:Embedding set for node 'Output 32597951'.
# INFO:__main__:Created task node for 32597951 with embedding shape: (17, 17)
# INFO:__main__:Node 'Task 3345333e' initialized.
# INFO:__main__:Node 'Output 3345333e' initialized.
# INFO:__main__:Embedding set for node 'Task 3345333e'.
# INFO:__main__:Embedding set for node 'Output 3345333e'.
# INFO:__main__:Created task node for 3345333e with embedding shape: (16, 16)
# INFO:__main__:Node 'Task 3345333e' initialized.
# INFO:__main__:Node 'Output 3345333e' initialized.
# INFO:__main__:Embedding set for node 'Task 3345333e'.
# INFO:__main__:Embedding set for node 'Output 3345333e'.
# INFO:__main__:Created task node for 3345333e with embedding shape: (16, 16)
# INFO:__main__:Node 'Task 3428a4f5' initialized.
# INFO:__main__:Node 'Output 3428a4f5' initialized.
# INFO:__main__:Embedding set for node 'Task 3428a4f5'.
# INFO:__main__:Embedding set for node 'Output 3428a4f5'.
# INFO:__main__:Created task node for 3428a4f5 with embedding shape: (13, 5)
# INFO:__main__:Node 'Task 3428a4f5' initialized.
# INFO:__main__:Node 'Output 3428a4f5' initialized.
# INFO:__main__:Embedding set for node 'Task 3428a4f5'.
# INFO:__main__:Embedding set for node 'Output 3428a4f5'.
# INFO:__main__:Created task node for 3428a4f5 with embedding shape: (13, 5)
# INFO:__main__:Node 'Task 3428a4f5' initialized.
# INFO:__main__:Node 'Output 3428a4f5' initialized.
# INFO:__main__:Embedding set for node 'Task 3428a4f5'.
# INFO:__main__:Embedding set for node 'Output 3428a4f5'.
# INFO:__main__:Created task node for 3428a4f5 with embedding shape: (13, 5)
# INFO:__main__:Node 'Task 3428a4f5' initialized.
# INFO:__main__:Node 'Output 3428a4f5' initialized.
